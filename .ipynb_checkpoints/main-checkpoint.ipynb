# %%
#load libraries
import pandas as pd
import os as os
import numpy as np
import re
import ipywidgets as widgets
from ipywidgets import interactive
import seaborn as sns
import plotly
import plotly.plotly as py
plotly.tools.set_credentials_file(username='jeremielamboley', api_key='Vl2N6wO66g1b8UXimcav')

# display option
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)

# %% [markdown]
# ## scraped database from https://www.henleypassportindex.com

# %%
# scrapping script here: https://github.com/jeremielamboley/world-passport-power-rank-enriched/blob/master/henley_passport_index_data_collection.ipynb
df_visa_free = pd.read_csv('https://raw.githubusercontent.com/jeremielamboley/henley/master/henley_visa_free_11_01_2019.csv', encoding = "ISO-8859-1")

# %%
df_visa_free.rename(columns={'passport': 'passportfrom_alpha_2code'}, inplace=True)
df_visa_free.rename(columns={'to': 'countryto_alpha_2code'}, inplace=True)

# %%
df_visa_free.shape
# Out:
# (45173, 3)

# %%
df_visa_free['passportfrom_alpha_2code'].nunique()
# Out:
# 198

# %%
df_visa_free['countryto_alpha_2code'].nunique()
# Out:
# 226

# %%
# Let's consider the passport holders countries as a country which gives visa-free access
df_visa_free.loc[df_visa_free['passportfrom_alpha_2code'] == df_visa_free['countryto_alpha_2code'], 'visafree'] = 1

# %%
# visafree matrix preview
df_visa_free.sample(5)
# Out:
#       passportfrom_alpha_2code countryto_alpha_2code  visafree
# 18878                       MZ                    BG         0
# 31878                       KZ                    SS         0
# 7616                        TN                    FW         0
# 36058                       EE                    FR         1
# 25979                       NI                    TL         1

# %%
# Nationals have visa free access to their own countries
df_visa_free[df_visa_free.passportfrom_alpha_2code == df_visa_free.countryto_alpha_2code].head()
# Out:
#     passportfrom_alpha_2code countryto_alpha_2code  visafree
# 9                         AM                    AM         1
# 234                       AG                    AG         1
# 267                       AO                    AO         1
# 316                       AR                    AR         1
# 351                       DZ                    DZ         1

# %% [markdown]
# ## List of world countries with ISO codes
# ### Source Wikipedia https://en.wikipedia.org/wiki/List_of_ISO_3166_country_codes
# ### Project by Radcliff https://gist.github.com/radcliff/f09c0f88344a7fcef373

# %%
df_iso = pd.read_csv('https://gist.githubusercontent.com/radcliff/f09c0f88344a7fcef373/raw/2753c482ad091c54b1822288ad2e4811c021d8ec/wikipedia-iso-country-codes.csv', encoding = "utf8")

# %%
df_iso.rename(columns={'English short name lower case': 'Country name'}, inplace=True)
df_iso.rename(columns={'Alpha-2 code': 'country_alpha_2code'}, inplace=True)
df_iso.rename(columns={'Alpha-3 code': 'country_alpha_3code'}, inplace=True)
df_iso.rename(columns={'Numeric code': 'country_numeric_code'}, inplace=True)
df_iso = df_iso.drop(['ISO 3166-2'], axis=1)

# %%
df_iso.shape
# Out:
# (246, 4)

# %%
df_iso.sample(5)
# Out:
#                     Country name country_alpha_2code country_alpha_3code  \
# 36                      Cambodia                  KH                 KHM
# 118                   Kyrgyzstan                  KG                 KGZ
# 134                         Mali                  ML                 MLI
# 69   Falkland Islands (Malvinas)                  FK                 FLK
# 54                       Croatia                  HR                 HRV
#
#      country_numeric_code
# 36                    116
# 118                   417
# 134                   466
# 69                    238
# 54                    191

# %% [markdown]
# ## Add the Regions, Standard country or area codes for statistical use (M49)
# ## https://unstats.un.org/unsd/methodology/m49/overview/

# %%
df_regions = pd.read_csv('https://raw.githubusercontent.com/jeremielamboley/world-passport-power-rank-enriched/master/source_files/UNSD-M49-25-01-2019.csv', 
                        encoding = "ISO-8859-1", 
                        delimiter = ',',
                        header=0)

# %%
df_regions.sample(5)
# Out:
#      Global Code Global Name  Region Code Region Name  Sub-region Code  \
# 214            1       World        150.0      Europe            155.0
# 103            1       World         19.0    Americas            419.0
# 89             1       World         19.0    Americas            419.0
# 137            1       World        142.0        Asia             35.0
# 0              1       World          2.0      Africa             15.0
#
#                      Sub-region Name  Intermediate Region Code  \
# 214                   Western Europe                       NaN
# 103  Latin America and the Caribbean                       5.0
# 89   Latin America and the Caribbean                      13.0
# 137               South-eastern Asia                       NaN
# 0                    Northern Africa                       NaN
#
#     Intermediate Region Name              Country or Area  M49 Code  \
# 214                      NaN                      Germany       276
# 103            South America  Falkland Islands (Malvinas)       238
# 89           Central America                   Costa Rica       188
# 137                      NaN                    Singapore       702
# 0                        NaN                      Algeria        12
#
#     ISO-alpha3 Code Least Developed Countries (LDC)  \
# 214             DEU                             NaN
# 103             FLK                             NaN
# 89              CRI                             NaN
# 137             SGP                             NaN
# 0               DZA                             NaN
#
#     Land Locked Developing Countries (LLDC)  \
# 214                                     NaN
# 103                                     NaN
# 89                                      NaN
# 137                                     NaN
# 0                                       NaN
#
#     Small Island Developing States (SIDS) Developed / Developing Countries
# 214                                   NaN                        Developed
# 103                                   NaN                       Developing
# 89                                    NaN                       Developing
# 137                                     x                       Developing
# 0                                     NaN                       Developing

# %%
df_regions['Developed / Developing Countries'] = np.where(df_regions['Least Developed Countries (LDC)'] == 'x', 'Least Developed', df_regions['Developed / Developing Countries'])

# %%
df_regions.sample(5)
# Out:
#      Global Code Global Name  Region Code Region Name  Sub-region Code  \
# 103            1       World         19.0    Americas            419.0
# 166            1       World        142.0        Asia            145.0
# 231            1       World          9.0     Oceania             57.0
# 90             1       World         19.0    Americas            419.0
# 122            1       World        142.0        Asia            143.0
#
#                      Sub-region Name  Intermediate Region Code  \
# 103  Latin America and the Caribbean                       5.0
# 166                     Western Asia                       NaN
# 231                       Micronesia                       NaN
# 90   Latin America and the Caribbean                      13.0
# 122                     Central Asia                       NaN
#
#     Intermediate Region Name              Country or Area  M49 Code  \
# 103            South America  Falkland Islands (Malvinas)       238
# 166                      NaN         United Arab Emirates       784
# 231                      NaN                         Guam       316
# 90           Central America                  El Salvador       222
# 122                      NaN                   Uzbekistan       860
#
#     ISO-alpha3 Code Least Developed Countries (LDC)  \
# 103             FLK                             NaN
# 166             ARE                             NaN
# 231             GUM                             NaN
# 90              SLV                             NaN
# 122             UZB                             NaN
#
#     Land Locked Developing Countries (LLDC)  \
# 103                                     NaN
# 166                                     NaN
# 231                                     NaN
# 90                                      NaN
# 122                                       x
#
#     Small Island Developing States (SIDS) Developed / Developing Countries
# 103                                   NaN                       Developing
# 166                                   NaN                       Developing
# 231                                     x                       Developing
# 90                                    NaN                       Developing
# 122                                   NaN                       Developing

# %%
df_regions = df_regions[['ISO-alpha3 Code','Region Name','Sub-region Name','Developed / Developing Countries']]
df_regions = df_regions.rename(columns={'ISO-alpha3 Code':'country_alpha_3code'})
df_regions.sample(5)
# Out:
#     country_alpha_3code Region Name     Sub-region Name  \
# 24                  SSD      Africa  Sub-Saharan Africa
# 189                 LVA      Europe     Northern Europe
# 162                 SAU        Asia        Western Asia
# 193                 SWE      Europe     Northern Europe
# 139                 TLS        Asia  South-eastern Asia
#
#     Developed / Developing Countries
# 24                   Least Developed
# 189                        Developed
# 162                       Developing
# 193                        Developed
# 139                  Least Developed

# %% [markdown]
# ## GDP per countries in USD, 2016, from the United Nations Statistics Division
# ### Source: http://data.un.org/

# %%
df_GDP_UN = pd.read_csv('http://data.un.org/_Docs/SYB/CSV/SYB61_T13_GDP%20and%20GDP%20Per%20Capita.csv', 
                        encoding = "ISO-8859-1", 
                        delimiter = ',',
                        header=1)

# %%
# filter the data to GDP in 2016
df_GDP_UN = df_GDP_UN[df_GDP_UN['Series'] == 'GDP in current prices (millions of US dollars)']
df_GDP_UN = df_GDP_UN[df_GDP_UN.Year == 2016]

# %%
# Organize the data
df_GDP_UN['Value'] = df_GDP_UN['Value'].str.replace(',', '')
df_GDP_UN['Value'] = df_GDP_UN['Value'].astype(int)
# Renaming columns
df_GDP_UN.rename(columns={'Region/Country/Area': 'country_numeric_code'}, inplace=True)
df_GDP_UN.rename(columns={'Value': 'UN_GDP_currentPrices2016'}, inplace=True)
# Convert GDP from millions to billions
df_GDP_UN['UN_GDP_currentPrices2016_billions'] = df_GDP_UN['UN_GDP_currentPrices2016'] / 1000

# %%
df_GDP_UN.shape
# Out:
# (242, 8)

# %%
df_GDP_UN.sample(5)
# Out:
#       country_numeric_code Unnamed: 1  Year  \
# 898                     12    Algeria  2016
# 3745                   422    Lebanon  2016
# 1038                    32  Argentina  2016
# 2676                   231   Ethiopia  2016
# 1890                   148       Chad  2016
#
#                                               Series  \
# 898   GDP in current prices (millions of US dollars)
# 3745  GDP in current prices (millions of US dollars)
# 1038  GDP in current prices (millions of US dollars)
# 2676  GDP in current prices (millions of US dollars)
# 1890  GDP in current prices (millions of US dollars)
#
#       UN_GDP_currentPrices2016 Footnotes  \
# 898                     159049       NaN
# 3745                     50458       NaN
# 1038                    545866       NaN
# 2676                     70315       NaN
# 1890                     11267       NaN
#
#                                                  Source  \
# 898   United Nations Statistics Division, New York, ...
# 3745  United Nations Statistics Division, New York, ...
# 1038  United Nations Statistics Division, New York, ...
# 2676  United Nations Statistics Division, New York, ...
# 1890  United Nations Statistics Division, New York, ...
#
#       UN_GDP_currentPrices2016_billions
# 898                             159.049
# 3745                             50.458
# 1038                            545.866
# 2676                             70.315
# 1890                             11.267

# %%
df_GDP_UN = df_GDP_UN[['country_numeric_code','UN_GDP_currentPrices2016_billions']]

# %% [markdown]
# ### World total GDP for 2016 to get a % of coverage per passport

# %%
# country code = 1 for the world aggregate
df_GDP_UN['UN_World_GDP_percent'] = df_GDP_UN['UN_GDP_currentPrices2016_billions'] / df_GDP_UN[df_GDP_UN['country_numeric_code'] == 1].iloc[0,1]

# %%
df_GDP_UN.sample(5)
# Out:
#       country_numeric_code  UN_GDP_currentPrices2016_billions  \
# 4817                   591                             55.188
# 6                        1                          75648.868
# 2170                   384                             36.768
# 646                     39                           3693.991
# 1974                   344                            320.912
#
#       UN_World_GDP_percent
# 4817              0.000730
# 6                 1.000000
# 2170              0.000486
# 646               0.048831
# 1974              0.004242

# %% [markdown]
# # Population and surface, 2015, from the United Nations Statistics Division

# %% [markdown]
# ### Source: http://data.un.org/

# %%
df_population_surface_UN = pd.read_csv('http://data.un.org/_Docs/SYB/CSV/SYB61_T02_Population,%20Surface%20Area%20and%20Density.csv', 
                        encoding = "ISO-8859-1", 
                        delimiter = ',',
                        header=1)

# %%
# filter the data to GDP in 2015
df_population_surface_UN = df_population_surface_UN[(df_population_surface_UN['Series'] == 'Population mid-year estimates (millions)') | (df_population_surface_UN['Series'] == 'Surface area (thousand km2)')]
df_population_surface_UN = df_population_surface_UN[df_population_surface_UN['Year'] == 2015]

# %%
# Organize the data
df_population_surface_UN['Value'] = df_population_surface_UN['Value'].str.replace(',', '')
df_population_surface_UN['Value'] = df_population_surface_UN['Value'].astype(float)

# %%
df_population_surface_UN = df_population_surface_UN[['Region/Country/Area','Series','Value']]
df_population_surface_UN.rename(columns={'Region/Country/Area': 'country_numeric_code'}, inplace=True)

# %%
# pivot and un-pivot
df_population_surface_UN = df_population_surface_UN.pivot(index='country_numeric_code', columns='Series', values='Value')
df_population_surface_UN = pd.DataFrame(df_population_surface_UN.to_records())

# %%
# get the world total for population and surface
df_population_UN_world = df_population_surface_UN[(df_population_surface_UN.country_numeric_code == 1)].iloc[0,1]
df_surface_UN_world = df_population_surface_UN[(df_population_surface_UN.country_numeric_code == 1)].iloc[0,2]

# %%
# World Population mid-year estimates 7383 millions, 2015
# Source: United Nations Statistics Division, New York, World Population Prospects: The 2017 Revision, last accessed June 2017.
df_population_surface_UN['UN_population_Value_2015_percent'] = (df_population_surface_UN['Population mid-year estimates (millions)'] / df_population_UN_world)

# %%
df_population_surface_UN['Surface_area_covered_percent'] = (df_population_surface_UN['Surface area (thousand km2)'] / df_surface_UN_world)

# %%
df_population_surface_UN.sample(5)
# Out:
#      country_numeric_code  Population mid-year estimates (millions)  \
# 249                   840                                    319.93
# 199                   643                                    143.89
# 221                   724                                     46.40
# 29                     48                                      1.37
# 178                   566                                    181.18
#
#      Surface area (thousand km2)  UN_population_Value_2015_percent  \
# 249                       9834.0                          0.043333
# 199                      17098.0                          0.019489
# 221                        506.0                          0.006285
# 29                           1.0                          0.000186
# 178                        924.0                          0.024540
#
#      Surface_area_covered_percent
# 249                      0.072223
# 199                      0.125571
# 221                      0.003716
# 29                       0.000007
# 178                      0.006786

# %% [markdown]
# # Unesco World Heritage list

# %% [markdown]
# ### https://whc.unesco.org/en/syndication

# %%
# Fetch the data from the Unesco website
unesco = pd.read_excel('https://whc.unesco.org/en/list/xls/whc-sites-2018.xls', encoding="Windows-1252",header=0)
unesco = unesco.reindex(['name_en', 'iso_code'], axis="columns")

# %%
# check the shape
unesco.shape
# Out:
# (1092, 2)

# %%
# Some values are comma separated and need to be reformated
unesco.tail(5)
# Out:
#                                                 name_en iso_code
# 1087  Prehistoric Rock Art Sites in the Côa Valley a...    pt,es
# 1088                                     Uvs Nuur Basin    ru,mn
# 1089                               Landscapes of Dauria    ru,mn
# 1090            Heritage of Mercury. Almadén and Idrija    si,es
# 1091                     Mosi-oa-Tunya / Victoria Falls    zm,zw

# %%
# Split the values
unesco = pd.concat([unesco['name_en'], unesco['iso_code'].str.split(',', expand=True)], axis=1)

unesco2 = []
for i in range(0,11):
    temp = unesco.loc[:,['name_en',i]]
    temp.columns = ['name_en','countryto_alpha_2code']
    unesco2.append(temp)
unesco2 = pd.concat(unesco2, ignore_index=True)

# Remove empty values
unesco2 = unesco2.replace(to_replace='None', value=np.nan).dropna().reset_index(drop=True)
# preview
unesco2.sample(5)
# Out:
#                                        name_en countryto_alpha_2code
# 64                   Historic Centre of Brugge                    be
# 79   Old Bridge Area of the Old City of Mostar                    ba
# 993                       Derwent Valley Mills                    gb
# 89             Serra da Capivara National Park                    br
# 941                 Historic Areas of Istanbul                    tr

# %%
# create a pivot table
unesco_pivot = pd.pivot_table(unesco2,index=['countryto_alpha_2code'], aggfunc='count')
unesco_pivot = pd.DataFrame(unesco_pivot.to_records())
unesco_pivot = unesco_pivot.rename(columns = {'name_en' :'unesco_total_sites'})
unesco_pivot = unesco_pivot.sort_values('unesco_total_sites',ascending=False)

# %%
# Count the total of world unesco sites
unesco_total_sites = unesco_pivot['unesco_total_sites'].sum()
# create the % of sites located in each country
unesco_pivot['unesco_total_sites_percent'] = (unesco_pivot['unesco_total_sites'] / unesco_total_sites)

# %%
# change to uppercase
unesco_pivot['countryto_alpha_2code'] = unesco_pivot['countryto_alpha_2code'].str.upper()

# %%
unesco_pivot.sample(5)
# Out:
#     countryto_alpha_2code  unesco_total_sites  unesco_total_sites_percent
# 48                     ES                  47                    0.040309
# 144                    SV                   1                    0.000858
# 67                     IE                   2                    0.001715
# 65                     HU                   8                    0.006861
# 21                     BW                   2                    0.001715

# %% [markdown]
# ## Intersect df_iso and df_regions

# %%
df_iso = pd.merge(df_iso, df_regions, how='left', on='country_alpha_3code')
df_iso.sample(5)
# Out:
#           Country name country_alpha_2code country_alpha_3code  \
# 85             Grenada                  GD                 GRD
# 203       South Africa                  ZA                 ZAF
# 53       Côte d'Ivoire                  CI                 CIV
# 186        Saint Lucia                  LC                 LCA
# 65   Equatorial Guinea                  GQ                 GNQ
#
#      country_numeric_code Region Name                  Sub-region Name  \
# 85                    308    Americas  Latin America and the Caribbean
# 203                   710      Africa               Sub-Saharan Africa
# 53                    384      Africa               Sub-Saharan Africa
# 186                   662    Americas  Latin America and the Caribbean
# 65                    226      Africa               Sub-Saharan Africa
#
#     Developed / Developing Countries
# 85                        Developing
# 203                       Developing
# 53                        Developing
# 186                       Developing
# 65                        Developing

# %% [markdown]
# ## Intersect df_visa_free and df_iso on 'country to'

# %%
# copy df_visa_free, rename the columns from centadata and hauntedhouse
df_visa_free2 = df_visa_free.copy()

# %%
df_visa_free2.rename(columns={'countryto_alpha_2code': 'country_alpha_2code'}, inplace=True)

# %%
# Intersect on 'countryto_alpha_2code'
df = pd.merge(df_visa_free2, df_iso, on=['country_alpha_2code'], how='left')

# %%
df.rename(columns={'country_alpha_2code': 'countryto_alpha_2code'}, inplace=True)
df.rename(columns={'Country name': 'countryto_Country_name'}, inplace=True)
df.rename(columns={'country_alpha_3code': 'countryto_country_alpha_3code'}, inplace=True)
df.rename(columns={'country_numeric_code': 'countryto_country_numeric_code'}, inplace=True)
df.rename(columns={'Region Name': 'countryto_Region_Name'}, inplace=True)
df.rename(columns={'Sub-region Name': 'countryto_Sub-region_Name'}, inplace=True)
df.rename(columns={'Developed / Developing Countries': 'countryto_Developed_Developing_Countries'}, inplace=True)

# %%
df['passportfrom_alpha_2code'].nunique()
# Out:
# 198

# %%
df['countryto_alpha_2code'].nunique()
# Out:
# 226

# %%
cols = df.columns.tolist()
cols
# Out:
# ['passportfrom_alpha_2code',
#  'countryto_alpha_2code',
#  'visafree',
#  'countryto_Country_name',
#  'countryto_country_alpha_3code',
#  'countryto_country_numeric_code',
#  'countryto_Region_Name',
#  'countryto_Sub-region_Name',
#  'countryto_Developed_Developing_Countries']

# %%
df.sample(5)
# Out:
#       passportfrom_alpha_2code countryto_alpha_2code  visafree  \
# 16669                       SB                    PY         0
# 7385                        ZW                    TW         0
# 9108                        SK                    AL         1
# 42169                       BB                    MK         1
# 41908                       CN                    PS         0
#
#                            countryto_Country_name  \
# 16669                                    Paraguay
# 7385                    Taiwan, Province of China
# 9108                                      Albania
# 42169  Macedonia, the former Yugoslav Republic of
# 41908             Palestinian Territory, Occupied
#
#       countryto_country_alpha_3code  countryto_country_numeric_code  \
# 16669                           PRY                           600.0
# 7385                            TWN                           158.0
# 9108                            ALB                             8.0
# 42169                           MKD                           807.0
# 41908                           PSE                           275.0
#
#       countryto_Region_Name        countryto_Sub-region_Name  \
# 16669              Americas  Latin America and the Caribbean
# 7385                    NaN                              NaN
# 9108                 Europe                  Southern Europe
# 42169                Europe                  Southern Europe
# 41908                  Asia                     Western Asia
#
#       countryto_Developed_Developing_Countries
# 16669                               Developing
# 7385                                       NaN
# 9108                                 Developed
# 42169                                Developed
# 41908                               Developing

# %% [markdown]
# ## Intersect df_visa_free and df_iso on 'passport'

# %%
df_iso.rename(columns={'country_alpha_2code': 'passportfrom_alpha_2code'}, inplace=True)

# %%
# Intersect on 'passportfrom_alpha_2code'
df = pd.merge(df, df_iso, on=['passportfrom_alpha_2code'], how='left')

# %%
df_iso.rename(columns={'passportfrom_alpha_2code': 'country_alpha_2code'}, inplace=True)

# %%
# 
df.rename(columns={'Country name': 'passportfrom_Country_name'}, inplace=True)
df.rename(columns={'Region Name': 'passportfrom_Region_Name'}, inplace=True)
df.rename(columns={'Sub-region Name': 'passportfrom_Sub-region_Name'}, inplace=True)
df.rename(columns={'Developed / Developing Countries': 'passportfrom_Developed_Developing_Countries'}, inplace=True)

# %%
df = df.drop(['country_alpha_3code'], axis=1)
df = df.drop(['country_numeric_code'], axis=1)

# %%
df.sample(5)
# Out:
#       passportfrom_alpha_2code countryto_alpha_2code  visafree  \
# 24042                       LU                    SZ         1
# 8660                        LC                    DK         1
# 38187                       BE                    BF         1
# 38751                       EC                    IT         0
# 6690                        US                    ID         1
#
#       countryto_Country_name countryto_country_alpha_3code  \
# 24042              Swaziland                           SWZ
# 8660                 Denmark                           DNK
# 38187           Burkina Faso                           BFA
# 38751                  Italy                           ITA
# 6690               Indonesia                           IDN
#
#        countryto_country_numeric_code countryto_Region_Name  \
# 24042                           748.0                Africa
# 8660                            208.0                Europe
# 38187                           854.0                Africa
# 38751                           380.0                Europe
# 6690                            360.0                  Asia
#
#       countryto_Sub-region_Name countryto_Developed_Developing_Countries  \
# 24042        Sub-Saharan Africa                               Developing
# 8660            Northern Europe                                Developed
# 38187        Sub-Saharan Africa                          Least Developed
# 38751           Southern Europe                                Developed
# 6690         South-eastern Asia                               Developing
#
#       passportfrom_Country_name passportfrom_Region_Name  \
# 24042                Luxembourg                   Europe
# 8660                Saint Lucia                 Americas
# 38187                   Belgium                   Europe
# 38751                   Ecuador                 Americas
# 6690              United States                 Americas
#
#           passportfrom_Sub-region_Name  \
# 24042                   Western Europe
# 8660   Latin America and the Caribbean
# 38187                   Western Europe
# 38751  Latin America and the Caribbean
# 6690                  Northern America
#
#       passportfrom_Developed_Developing_Countries
# 24042                                   Developed
# 8660                                   Developing
# 38187                                   Developed
# 38751                                  Developing
# 6690                                    Developed

# %% [markdown]
# ## Intersect df and df_GDP_UN

# %%
df_GDP_UN2 = df_GDP_UN.copy()
df_GDP_UN2.rename(columns={'country_numeric_code': 'countryto_country_numeric_code'}, inplace=True)

# %%
df2 = pd.merge(df, df_GDP_UN2, on=['countryto_country_numeric_code'], how='left')

# %%
df2.rename(columns={'UN_GDP_currentPrices2016_billions': 'countryto_UN_GDP_currentPrices2016'}, inplace=True)

# %%
df2.sample(5)
# Out:
#       passportfrom_alpha_2code countryto_alpha_2code  visafree  \
# 29134                       ME                    ZM         1
# 34607                       KH                    AT         0
# 36818                       CF                    KM         1
# 28094                       MU                    PT         1
# 8800                        SD                    ER         1
#
#       countryto_Country_name countryto_country_alpha_3code  \
# 29134                 Zambia                           ZMB
# 34607                Austria                           AUT
# 36818                Comoros                           COM
# 28094               Portugal                           PRT
# 8800                 Eritrea                           ERI
#
#        countryto_country_numeric_code countryto_Region_Name  \
# 29134                           894.0                Africa
# 34607                            40.0                Europe
# 36818                           174.0                Africa
# 28094                           620.0                Europe
# 8800                            232.0                Africa
#
#       countryto_Sub-region_Name countryto_Developed_Developing_Countries  \
# 29134        Sub-Saharan Africa                          Least Developed
# 34607            Western Europe                                Developed
# 36818        Sub-Saharan Africa                          Least Developed
# 28094           Southern Europe                                Developed
# 8800         Sub-Saharan Africa                          Least Developed
#
#       passportfrom_Country_name passportfrom_Region_Name  \
# 29134                Montenegro                   Europe
# 34607                  Cambodia                     Asia
# 36818  Central African Republic                   Africa
# 28094                 Mauritius                   Africa
# 8800                      Sudan                   Africa
#
#       passportfrom_Sub-region_Name  \
# 29134              Southern Europe
# 34607           South-eastern Asia
# 36818           Sub-Saharan Africa
# 28094           Sub-Saharan Africa
# 8800               Northern Africa
#
#       passportfrom_Developed_Developing_Countries  \
# 29134                                   Developed
# 34607                             Least Developed
# 36818                             Least Developed
# 28094                                  Developing
# 8800                              Least Developed
#
#        countryto_UN_GDP_currentPrices2016  UN_World_GDP_percent
# 29134                              21.063              0.000278
# 34607                             390.800              0.005166
# 36818                               1.150              0.000015
# 28094                             204.837              0.002708
# 8800                                5.414              0.000072

# %% [markdown]
# ## Intersect df2 and df_population_UN

# %%
df_population_UN2 = df_population_surface_UN.copy()
df_population_UN2.rename(columns={'country_numeric_code': 'countryto_country_numeric_code'}, inplace=True)

# %%
df3 = pd.merge(df2, df_population_UN2, on=['countryto_country_numeric_code'], how='left')

# %%
df3.rename(columns={'UN_population_Value_2015_millions': 'countryto_UN_population_Value_2015_millions'}, inplace=True)
df3.rename(columns={'Population mid-year estimates (millions)': 'countryto_UN_population_Value_2015_millions'}, inplace=True)
df3.rename(columns={'Surface area (thousand km2)': 'countryto_Surface_area'}, inplace=True)

# %%
df3.sample(5)
# Out:
#       passportfrom_alpha_2code countryto_alpha_2code  visafree  \
# 9293                        KN                    GQ         0
# 39001                       HT                    UZ         0
# 17437                       ES                    SY         0
# 36996                       GE                    LK         1
# 2895                        BW                    LY         0
#
#        countryto_Country_name countryto_country_alpha_3code  \
# 9293        Equatorial Guinea                           GNQ
# 39001              Uzbekistan                           UZB
# 17437    Syrian Arab Republic                           SYR
# 36996               Sri Lanka                           LKA
# 2895   Libyan Arab Jamahiriya                           LBY
#
#        countryto_country_numeric_code countryto_Region_Name  \
# 9293                            226.0                Africa
# 39001                           860.0                  Asia
# 17437                           760.0                  Asia
# 36996                           144.0                  Asia
# 2895                            434.0                Africa
#
#       countryto_Sub-region_Name countryto_Developed_Developing_Countries  \
# 9293         Sub-Saharan Africa                               Developing
# 39001              Central Asia                               Developing
# 17437              Western Asia                               Developing
# 36996             Southern Asia                               Developing
# 2895            Northern Africa                               Developing
#
#       passportfrom_Country_name passportfrom_Region_Name  \
# 9293      Saint Kitts and Nevis                 Americas
# 39001                     Haiti                 Americas
# 17437                     Spain                   Europe
# 36996                   Georgia                     Asia
# 2895                   Botswana                   Africa
#
#           passportfrom_Sub-region_Name  \
# 9293   Latin America and the Caribbean
# 39001  Latin America and the Caribbean
# 17437                  Southern Europe
# 36996                     Western Asia
# 2895                Sub-Saharan Africa
#
#       passportfrom_Developed_Developing_Countries  \
# 9293                                   Developing
# 39001                             Least Developed
# 17437                                   Developed
# 36996                                  Developing
# 2895                                   Developing
#
#        countryto_UN_GDP_currentPrices2016  UN_World_GDP_percent  \
# 9293                               10.678              0.000141
# 39001                              67.779              0.000896
# 17437                              22.163              0.000293
# 36996                              81.322              0.001075
# 2895                               42.960              0.000568
#
#        countryto_UN_population_Value_2015_millions  countryto_Surface_area  \
# 9293                                          1.18                    28.0
# 39001                                        30.98                   449.0
# 17437                                        18.74                   185.0
# 36996                                        20.71                    66.0
# 2895                                          6.24                  1676.0
#
#        UN_population_Value_2015_percent  Surface_area_covered_percent
# 9293                           0.000160                      0.000206
# 39001                          0.004196                      0.003298
# 17437                          0.002538                      0.001359
# 36996                          0.002805                      0.000485
# 2895                           0.000845                      0.012309

# %% [markdown]
# ## Intersect df3 and unesco_pivot

# %%
unesco_pivot2 = unesco_pivot.copy()

# %%
df4 = pd.merge(df3, unesco_pivot2, on=['countryto_alpha_2code'], how='left')

# %%
df4.sample(5)
# Out:
#       passportfrom_alpha_2code countryto_alpha_2code  visafree  \
# 42859                       BB                    MZ         1
# 34645                       BO                    AU         0
# 65                          AM                    SZ         0
# 23846                       PW                    UZ         0
# 21057                       MD                    PF         1
#
#       countryto_Country_name countryto_country_alpha_3code  \
# 42859             Mozambique                           MOZ
# 34645              Australia                           AUS
# 65                 Swaziland                           SWZ
# 23846             Uzbekistan                           UZB
# 21057       French Polynesia                           PYF
#
#        countryto_country_numeric_code countryto_Region_Name  \
# 42859                           508.0                Africa
# 34645                            36.0               Oceania
# 65                              748.0                Africa
# 23846                           860.0                  Asia
# 21057                           258.0               Oceania
#
#        countryto_Sub-region_Name countryto_Developed_Developing_Countries  \
# 42859         Sub-Saharan Africa                          Least Developed
# 34645  Australia and New Zealand                                Developed
# 65            Sub-Saharan Africa                               Developing
# 23846               Central Asia                               Developing
# 21057                  Polynesia                               Developing
#
#              passportfrom_Country_name passportfrom_Region_Name  \
# 42859                         Barbados                 Americas
# 34645  Bolivia, Plurinational State of                 Americas
# 65                             Armenia                     Asia
# 23846                            Palau                  Oceania
# 21057             Moldova, Republic of                   Europe
#
#           passportfrom_Sub-region_Name  \
# 42859  Latin America and the Caribbean
# 34645  Latin America and the Caribbean
# 65                        Western Asia
# 23846                       Micronesia
# 21057                   Eastern Europe
#
#       passportfrom_Developed_Developing_Countries  \
# 42859                                  Developing
# 34645                                  Developing
# 65                                     Developing
# 23846                                  Developing
# 21057                                   Developed
#
#        countryto_UN_GDP_currentPrices2016  UN_World_GDP_percent  \
# 42859                              10.930              0.000144
# 34645                            1304.463              0.017244
# 65                                  4.007              0.000053
# 23846                              67.779              0.000896
# 21057                               5.418              0.000072
#
#        countryto_UN_population_Value_2015_millions  countryto_Surface_area  \
# 42859                                        28.01                   799.0
# 34645                                        23.80                  7692.0
# 65                                            1.32                    17.0
# 23846                                        30.98                   449.0
# 21057                                         0.28                     4.0
#
#        UN_population_Value_2015_percent  Surface_area_covered_percent  \
# 42859                          0.003794                      0.005868
# 34645                          0.003224                      0.056492
# 65                             0.000179                      0.000125
# 23846                          0.004196                      0.003298
# 21057                          0.000038                      0.000029
#
#        unesco_total_sites  unesco_total_sites_percent
# 42859                 1.0                    0.000858
# 34645                19.0                    0.016295
# 65                    NaN                         NaN
# 23846                 5.0                    0.004288
# 21057                 NaN                         NaN

# %% [markdown]
# ## Reordering the columns

# %%
df4 = df4.reset_index(drop=True)
cols = df4.columns.tolist()
cols
# Out:
# ['passportfrom_alpha_2code',
#  'countryto_alpha_2code',
#  'visafree',
#  'countryto_Country_name',
#  'countryto_country_alpha_3code',
#  'countryto_country_numeric_code',
#  'countryto_Region_Name',
#  'countryto_Sub-region_Name',
#  'countryto_Developed_Developing_Countries',
#  'passportfrom_Country_name',
#  'passportfrom_Region_Name',
#  'passportfrom_Sub-region_Name',
#  'passportfrom_Developed_Developing_Countries',
#  'countryto_UN_GDP_currentPrices2016',
#  'UN_World_GDP_percent',
#  'countryto_UN_population_Value_2015_millions',
#  'countryto_Surface_area',
#  'UN_population_Value_2015_percent',
#  'Surface_area_covered_percent',
#  'unesco_total_sites',
#  'unesco_total_sites_percent']

# %%
df4 = df4[['passportfrom_alpha_2code','passportfrom_Country_name','passportfrom_Sub-region_Name','countryto_alpha_2code','countryto_Country_name','countryto_country_alpha_3code', 'countryto_country_numeric_code','countryto_UN_GDP_currentPrices2016','UN_World_GDP_percent', 'countryto_UN_population_Value_2015_millions','UN_population_Value_2015_percent','countryto_Surface_area','Surface_area_covered_percent','unesco_total_sites','unesco_total_sites_percent','visafree']]

# %%
df4['passportfrom_alpha_2code'].nunique()
# Out:
# 198

# %%
df4.head(5)
# Out:
#   passportfrom_alpha_2code passportfrom_Country_name  \
# 0                       AM                   Armenia
# 1                       AM                   Armenia
# 2                       AM                   Armenia
# 3                       AM                   Armenia
# 4                       AM                   Armenia
#
#   passportfrom_Sub-region_Name countryto_alpha_2code countryto_Country_name  \
# 0                 Western Asia                    AF            Afghanistan
# 1                 Western Asia                    AL                Albania
# 2                 Western Asia                    DZ                Algeria
# 3                 Western Asia                    AS         American Samoa
# 4                 Western Asia                    AD                Andorra
#
#   countryto_country_alpha_3code  countryto_country_numeric_code  \
# 0                           AFG                             4.0
# 1                           ALB                             8.0
# 2                           DZA                            12.0
# 3                           ASM                            16.0
# 4                           AND                            20.0
#
#    countryto_UN_GDP_currentPrices2016  UN_World_GDP_percent  \
# 0                              20.235              0.000267
# 1                              11.864              0.000157
# 2                             159.049              0.002102
# 3                                 NaN                   NaN
# 4                               2.858              0.000038
#
#    countryto_UN_population_Value_2015_millions  \
# 0                                        33.74
# 1                                         2.92
# 2                                        39.87
# 3                                         0.06
# 4                                         0.08
#
#    UN_population_Value_2015_percent  countryto_Surface_area  \
# 0                          0.004570                   653.0
# 1                          0.000396                    29.0
# 2                          0.005400                  2382.0
# 3                          0.000008                     0.0
# 4                          0.000011                     0.0
#
#    Surface_area_covered_percent  unesco_total_sites  \
# 0                      0.004796                 2.0
# 1                      0.000213                 3.0
# 2                      0.017494                 7.0
# 3                      0.000000                 NaN
# 4                      0.000000                 1.0
#
#    unesco_total_sites_percent  visafree
# 0                    0.001715         0
# 1                    0.002573         1
# 2                    0.006003         0
# 3                         NaN         0
# 4                    0.000858         0

# %% [markdown]
# ## Pandas pivot_table 'passport FROM'

# %%
df_pivot = pd.pivot_table(df4[df4.visafree == 1],index='passportfrom_Country_name',values=['countryto_UN_GDP_currentPrices2016','UN_World_GDP_percent','countryto_UN_population_Value_2015_millions','UN_population_Value_2015_percent','countryto_Surface_area','Surface_area_covered_percent','unesco_total_sites','unesco_total_sites_percent','visafree'], aggfunc=np.sum, margins=False,dropna=True)
df_pivot.sort_values('visafree', ascending=False)
df_pivot.head(5)
# Out:
#                            Surface_area_covered_percent  UN_World_GDP_percent  \
# passportfrom_Country_name
# Afghanistan                                    0.043228              0.006096
# Albania                                        0.235925              0.304711
# Algeria                                        0.126034              0.040480
# Andorra                                        0.541803              0.758506
# Angola                                         0.123030              0.044224
#
#                            UN_population_Value_2015_percent  \
# passportfrom_Country_name
# Afghanistan                                        0.053354
# Albania                                            0.269534
# Algeria                                            0.132256
# Andorra                                            0.424193
# Angola                                             0.153492
#
#                            countryto_Surface_area  \
# passportfrom_Country_name
# Afghanistan                                5886.0
# Albania                                   32124.0
# Algeria                                   17161.0
# Andorra                                   73773.0
# Angola                                    16752.0
#
#                            countryto_UN_GDP_currentPrices2016  \
# passportfrom_Country_name
# Afghanistan                                           461.147
# Albania                                             23051.078
# Algeria                                              3062.282
# Andorra                                             57380.122
# Angola                                               3345.458
#
#                            countryto_UN_population_Value_2015_millions  \
# passportfrom_Country_name
# Afghanistan                                                     393.91
# Albania                                                        1989.97
# Algeria                                                         976.45
# Andorra                                                        3131.82
# Angola                                                         1133.23
#
#                            unesco_total_sites  unesco_total_sites_percent  \
# passportfrom_Country_name
# Afghanistan                              41.0                    0.035163
# Albania                                 640.0                    0.548885
# Algeria                                 164.0                    0.140652
# Andorra                                 916.0                    0.785592
# Angola                                  141.0                    0.120926
#
#                            visafree
# passportfrom_Country_name
# Afghanistan                      31
# Albania                         116
# Algeria                          51
# Andorra                         170
# Angola                           50

# %% [markdown]
# ## Turn the pivot table in a Data frame

# %%
df_pivot_flattened = pd.DataFrame(df_pivot.to_records())
df_pivot_flattened.sample(5)
# Out:
#     passportfrom_Country_name  Surface_area_covered_percent  \
# 60                      Gabon                      0.124675
# 194                     Yemen                      0.056829
# 173                Tajikistan                      0.249607
# 54                    Eritrea                      0.064467
# 112                Mauritania                      0.138614
#
#      UN_World_GDP_percent  UN_population_Value_2015_percent  \
# 60               0.051672                          0.162809
# 194              0.011428                          0.054281
# 173              0.070267                          0.177418
# 54               0.021901                          0.088683
# 112              0.049626                          0.161499
#
#      countryto_Surface_area  countryto_UN_GDP_currentPrices2016  \
# 60                  16976.0                            3908.950
# 194                  7738.0                             864.526
# 173                 33987.0                            5315.594
# 54                   8778.0                            1656.767
# 112                 18874.0                            3754.186
#
#      countryto_UN_population_Value_2015_millions  unesco_total_sites  \
# 60                                       1202.02               155.0
# 194                                       400.76                79.0
# 173                                      1309.88               201.0
# 54                                        654.75                84.0
# 112                                      1192.35               160.0
#
#      unesco_total_sites_percent  visafree
# 60                     0.132933        56
# 194                    0.067753        38
# 173                    0.172384        59
# 54                     0.072041        39
# 112                    0.137221        59

# %% [markdown]
# ## Pandas pivot_table 'passport TO'

# %%
df_pivot2 = pd.pivot_table(df4[df4.visafree == 1],index='countryto_Country_name',values=['visafree'], aggfunc=np.sum, margins=False,dropna=True)
df_pivot_flattened2 = pd.DataFrame(df_pivot2.to_records())
df_pivot_flattened2.rename(columns = {'countryto_Country_name':'passportfrom_Country_name','visafree':'visafreeTO'}, inplace=True)
df_pivot_flattened = pd.merge(df_pivot_flattened, df_pivot_flattened2, how='left', on='passportfrom_Country_name')
df_pivot_flattened.head()
# Out:
#   passportfrom_Country_name  Surface_area_covered_percent  \
# 0               Afghanistan                      0.043228
# 1                   Albania                      0.235925
# 2                   Algeria                      0.126034
# 3                   Andorra                      0.541803
# 4                    Angola                      0.123030
#
#    UN_World_GDP_percent  UN_population_Value_2015_percent  \
# 0              0.006096                          0.053354
# 1              0.304711                          0.269534
# 2              0.040480                          0.132256
# 3              0.758506                          0.424193
# 4              0.044224                          0.153492
#
#    countryto_Surface_area  countryto_UN_GDP_currentPrices2016  \
# 0                  5886.0                             461.147
# 1                 32124.0                           23051.078
# 2                 17161.0                            3062.282
# 3                 73773.0                           57380.122
# 4                 16752.0                            3345.458
#
#    countryto_UN_population_Value_2015_millions  unesco_total_sites  \
# 0                                       393.91                41.0
# 1                                      1989.97               640.0
# 2                                       976.45               164.0
# 3                                      3131.82               916.0
# 4                                      1133.23               141.0
#
#    unesco_total_sites_percent  visafree  visafreeTO
# 0                    0.035163        31           1
# 1                    0.548885       116          90
# 2                    0.140652        51           8
# 3                    0.785592       170          94
# 4                    0.120926        50          12

# %%
df_pivot_flattened['Surface_Rank'] = df_pivot_flattened['countryto_Surface_area'].rank(method='min', ascending=False).astype(int)
df_pivot_flattened['GDP_Rank'] = df_pivot_flattened['countryto_UN_GDP_currentPrices2016'].rank(method='min', ascending=False).astype(int)
df_pivot_flattened['Population_Rank'] = df_pivot_flattened['countryto_UN_population_Value_2015_millions'].rank(method='min', ascending=False).astype(int)
df_pivot_flattened['visafree_countries_Rank'] = df_pivot_flattened['visafree'].rank(method='min', ascending=False).astype(int)
df_pivot_flattened['unesco_total_sites_Rank'] = df_pivot_flattened['unesco_total_sites'].rank(method='min', ascending=False).astype(int)

# %% [markdown]
# ## Calculate the overall ranking

# %%
df_pivot_flattened['Overall_ranking_calculation'] = df_pivot_flattened[['visafree_countries_Rank','GDP_Rank','Surface_Rank','Population_Rank','unesco_total_sites_Rank']].sum(axis=1)

# %%
df_pivot_flattened['New_Overall_ranking'] = df_pivot_flattened['Overall_ranking_calculation'].rank(method='min', ascending=True).astype(int)

# %%
df_pivot_flattened
# Out:
#                  passportfrom_Country_name  Surface_area_covered_percent  \
# 0                              Afghanistan                      0.043228
# 1                                  Albania                      0.235925
# 2                                  Algeria                      0.126034
# 3                                  Andorra                      0.541803
# 4                                   Angola                      0.123030
# 5                      Antigua and Barbuda                      0.280937
# 6                                Argentina                      0.511721
# 7                                  Armenia                      0.332237
# 8                                Australia                      0.509636
# 9                                  Austria                      0.577826
# 10                              Azerbaijan                      0.257818
# 11                                 Bahamas                      0.426632
# 12                                 Bahrain                      0.149153
# 13                              Bangladesh                      0.056624
# 14                                Barbados                      0.450045
# 15                                 Belarus                      0.451323
# 16                                 Belgium                      0.577635
# 17                                  Belize                      0.233545
# 18                                   Benin                      0.149462
# 19                                  Bhutan                      0.113446
# 180                    0.224700        67          97           113       104
# 181                    0.360206       112          78            91        99
# 182                    0.136364        54           2           177       149
# 183                    0.538593       128         199           121        92
# 184                    0.114923        65         198           173       163
# 185                    0.653516       129          72            57        83
# 186                    0.773585       165          71            33        41
# 187                    0.776158       186          90            25        30
# 188                    0.754717       186          43            36        40
# 189                    0.722985       155          84            52        58
# 190                    0.179245        59          19           102       130
# 191                    0.572899       130         120            92        88
# 192                    0.656947       139          71            58        78
# 193                    0.120926        52          26           165       147
# 194                    0.067753        38          14           192       195
# 195                    0.129503        69         137           147       144
# 196                    0.132933        65         145           132       143
#
#      Population_Rank  visafree_countries_Rank  unesco_total_sites_Rank  \
# 0                196                      196                      197
# 1                 97                       93                       91
# 2                172                      168                      139
# 3                 41                       42                       28
# 4                162                      170                      160
# 5                 85                       57                       73
# 6                 50                       41                       33
# 7                127                      138                      119
# 8                 54                       25                       40
# 9                 33                       12                       19
# 10               142                      127                      125
# 11                10                       53                       51
# 12               116                      109                      114
# 13               187                      185                      193
# 14                 9                       51                       45
# 15                31                      112                       98
# 16                38                       19                       19
# 17               108                       96                      101
# 18               125                      138                      135
# 19               143                      152                      143
# 20               103                      111                      107
# 21                13                       91                       75
# 22               140                      108                      128
# 23                58                       40                       42
# 24                 5                       48                       41
# 25                61                       42                       47
# 26               135                      148                      155
# 27               163                      178                      174
# 28               131                      156                      156
# 29               174                      173                      184
# 30                56                       19                       42
# 31               118                      130                      133
# 32               179                      170                      176
# 33               139                      159                      166
# 34                23                       36                       14
# 35                60                      116                      113
# 36                92                       81                       78
# 37               160                      163                      154
# 38               175                      175                      177
# 39               177                      180                      183
# 40                73                       58                       57
# 41                72                       46                       52
# 42               151                      130                      132
# 43                65                       39                       49
# 44                30                       23                       24
# 45               130                      149                      147
# 46                18                        6                        7
# 47               178                      179                      179
# 48                88                       70                       76
# 49               133                      130                      122
# ..               ...                      ...                      ...
# 147               77                       55                       65
# 148               96                       62                       82
# 149               90                       64                       74
# 150               89                       78                       81
# 151                4                       46                        4
# 152              149                      143                      150
# 153              123                      119                      123
# 154              136                      149                      149
# 155               12                       76                       62
# 156                7                       55                       59
# 157              176                      137                      180
# 158                3                        2                        3
# 159               37                       28                       32
# 160               46                       28                       36
# 161              100                       75                       88
# 162              193                      194                      196
# 163              104                       96                      102
# 164               25                       10                       15
# 165              191                      180                      191
# 166              188                      189                      187
# 167              113                      110                      109
# 168              153                      120                      133
# 169               18                        6                        7
# 170               28                       12                       12
# 171              195                      194                      190
# 172                8                       58                       56
# 173              138                      143                      130
# 174              147                      124                      152
# 175              109                      115                      103
# 176              114                       98                       94
# 177              132                      152                      159
# 178               22                       84                       85
# 179               64                       60                       64
# 180              124                      127                      111
# 181               91                       95                       96
# 182              166                      159                      141
# 183              105                       81                       93
# 184              165                      133                      171
# 185               75                       78                       71
# 186                6                       49                       35
# 187               32                       12                       33
# 188               57                       12                       44
# 189               63                       53                       53
# 190              145                      143                      127
# 191               99                       76                       90
# 192               71                       69                       69
# 193              164                      165                      160
# 194              194                      192                      191
# 195              156                      124                      150
# 196              148                      133                      144
#
#      Overall_ranking_calculation  New_Overall_ranking
# 0                            983                  197
# 1                            481                   97
# 2                            794                  161
# 3                            161                   30
# 4                            808                  165
# 5                            391                   77
# 6                            216                   44
# 7                            597                  118
# 8                            197                   41
# 9                            106                   18
# 10                           626                  125
# 11                           222                   47
# 12                           585                  115
# 13                           946                  191
# 14                           201                   42
# 15                           392                   78
# 16                           125                   22
# 17                           520                  107
# 18                           662                  134
# 19                           739                  150
# 20                           519                  106
# 21                           303                   59
# 22                           641                  127
# 23                           243                   49
# 24                           104                   17
# 25                           269                   53
# 26                           728                  146
# 27                           849                  170
# 28                           748                  153
# 29                           882                  177
# 30                           191                   40
# 31                           643                  129
# 32                           885                  178
# 33                           751                  156
# 34                            95                   15
# 35                           505                  102
# 36                           410                   86
# 37                           809                  166
# 38                           866                  175
# 39                           900                  183
# 40                           343                   66
# 41                           298                   58
# 42                           652                  132
# 43                           273                   55
# 44                           140                   26
# 45                           725                  144
# 46                            50                    6
# 47                           899                  182
# 48                           394                   80
# 49                           636                  126
# ..                           ...                  ...
# 147                          341                   65
# 148                          437                   90
# 149                          401                   82
# 150                          407                   83
# 151                           64                   10
# 152                          750                  155
# 153                          619                  121
# 154                          733                  148
# 155                          243                   49
# 156                          216                   44
# 157                          849                  170
# 158                           12                    2
# 159                          169                   32
# 160                          185                   36
# 161                          448                   92
# 162                          973                  195
# 163                          486                   98
# 164                           88                   13
# 165                          939                  188
# 166                          941                  189
# 167                          550                  110
# 168                          689                  136
# 169                           50                    6
# 170                           82                   12
# 171                          961                  192
# 172                          175                   34
# 173                          651                  131
# 174                          708                  140
# 175                          511                  103
# 176                          533                  108
# 177                          744                  151
# 178                          358                   71
# 179                          349                   69
# 180                          579                  113
# 181                          472                   96
# 182                          792                  160
# 183                          492                   99
# 184                          805                  164
# 185                          364                   74
# 186                          164                   31
# 187                          132                   24
# 188                          189                   39
# 189                          279                   57
# 190                          647                  130
# 191                          445                   91
# 192                          345                   67
# 193                          801                  163
# 194                          964                  193
# 195                          721                  142
# 196                          700                  139
#
# [197 rows x 18 columns]

# %%
df_iso
# Out:
#                                      Country name country_alpha_2code  \
# 0                                     Afghanistan                  AF
# 1                                   Åland Islands                  AX
# 2                                         Albania                  AL
# 3                                         Algeria                  DZ
# 4                                  American Samoa                  AS
# 5                                         Andorra                  AD
# 6                                          Angola                  AO
# 7                                        Anguilla                  AI
# 8                                      Antarctica                  AQ
# 9                             Antigua and Barbuda                  AG
# 10                                      Argentina                  AR
# 11                                        Armenia                  AM
# 12                                          Aruba                  AW
# 13                                      Australia                  AU
# 14                                        Austria                  AT
# 15                                     Azerbaijan                  AZ
# 16                                        Bahamas                  BS
# 17                                        Bahrain                  BH
# 18                                     Bangladesh                  BD
# 19                                       Barbados                  BB
# 20                                        Belarus                  BY
# 21                                        Belgium                  BE
# 22                                         Belize                  BZ
# 23                                          Benin                  BJ
# 24                                        Bermuda                  BM
# 25                                         Bhutan                  BT
# 26                Bolivia, Plurinational State of                  BO
# 27                         Bosnia and Herzegovina                  BA
# 28                                       Botswana                  BW
# 29                                  Bouvet Island                  BV
# 30                                         Brazil                  BR
# 31                 British Indian Ocean Territory                  IO
# 32                              Brunei Darussalam                  BN
# 33                                       Bulgaria                  BG
# 34                                   Burkina Faso                  BF
# 35                                        Burundi                  BI
# 36                                       Cambodia                  KH
# 37                                       Cameroon                  CM
# 38                                         Canada                  CA
# 39                                     Cape Verde                  CV
# 40                                 Cayman Islands                  KY
# 41                       Central African Republic                  CF
# 42                                           Chad                  TD
# 43                                          Chile                  CL
# 44                                          China                  CN
# 45                               Christmas Island                  CX
# 46                        Cocos (Keeling) Islands                  CC
# 47                                       Colombia                  CO
# 48                                        Comoros                  KM
# 49                                          Congo                  CG
# ..                                            ...                 ...
# 196                                    Seychelles                  SC
# 197                                  Sierra Leone                  SL
# 198                                     Singapore                  SG
# 199                                      Slovakia                  SK
# 200                                      Slovenia                  SI
# 201                               Solomon Islands                  SB
# 202                                       Somalia                  SO
# 203                                  South Africa                  ZA
# 204  South Georgia and the South Sandwich Islands                  GS
# 205                                         Spain                  ES
# 206                                     Sri Lanka                  LK
# 207                                         Sudan                  SD
# 208                                      Suriname                  SR
# 209                        Svalbard and Jan Mayen                  SJ
# 210                                     Swaziland                  SZ
# 211                                        Sweden                  SE
# 212                                   Switzerland                  CH
# 213                          Syrian Arab Republic                  SY
# 214                     Taiwan, Province of China                  TW
# 215                                    Tajikistan                  TJ
# 216                  Tanzania, United Republic of                  TZ
# 217                                      Thailand                  TH
# 218                                   Timor-Leste                  TL
# 219                                          Togo                  TG
# 220                                       Tokelau                  TK
# 221                                         Tonga                  TO
# 222                           Trinidad and Tobago                  TT
# 223                                       Tunisia                  TN
# 224                                        Turkey                  TR
# 225                                  Turkmenistan                  TM
# 226                      Turks and Caicos Islands                  TC
# 227                                        Tuvalu                  TV
# 228                                        Uganda                  UG
# 229                                       Ukraine                  UA
# 230                          United Arab Emirates                  AE
# 231                                United Kingdom                  GB
# 232                                 United States                  US
# 233          United States Minor Outlying Islands                  UM
# 234                                       Uruguay                  UY
# 235                                    Uzbekistan                  UZ
# 236                                       Vanuatu                  VU
# 237             Venezuela, Bolivarian Republic of                  VE
# 238                                      Viet Nam                  VN
# 239                       Virgin Islands, British                  VG
# 240                          Virgin Islands, U.S.                  VI
# 241                             Wallis and Futuna                  WF
# 242                                Western Sahara                  EH
# 243                                         Yemen                  YE
# 244                                        Zambia                  ZM
# 245                                      Zimbabwe                  ZW
#
#     country_alpha_3code  country_numeric_code Region Name  \
# 0                   AFG                     4        Asia
# 1                   ALA                   248      Europe
# 2                   ALB                     8      Europe
# 3                   DZA                    12      Africa
# 4                   ASM                    16     Oceania
# 5                   AND                    20      Europe
# 6                   AGO                    24      Africa
# 7                   AIA                   660    Americas
# 8                   ATA                    10         NaN
# 9                   ATG                    28    Americas
# 10                  ARG                    32    Americas
# 11                  ARM                    51        Asia
# 12                  ABW                   533    Americas
# 13                  AUS                    36     Oceania
# 14                  AUT                    40      Europe
# 15                  AZE                    31        Asia
# 16                  BHS                    44    Americas
# 17                  BHR                    48        Asia
# 18                  BGD                    50        Asia
# 19                  BRB                    52    Americas
# 20                  BLR                   112      Europe
# 21                  BEL                    56      Europe
# 22                  BLZ                    84    Americas
# 23                  BEN                   204      Africa
# 24                  BMU                    60    Americas
# 25                  BTN                    64        Asia
# 26                  BOL                    68    Americas
# 27                  BIH                    70      Europe
# 28                  BWA                    72      Africa
# 29                  BVT                    74    Americas
# 30                  BRA                    76    Americas
# 31                  IOT                    86      Africa
# 32                  BRN                    96        Asia
# 33                  BGR                   100      Europe
# 34                  BFA                   854      Africa
# 35                  BDI                   108      Africa
# 36                  KHM                   116        Asia
# 37                  CMR                   120      Africa
# 38                  CAN                   124    Americas
# 39                  CPV                   132      Africa
# 40                  CYM                   136    Americas
# 41                  CAF                   140      Africa
# 42                  TCD                   148      Africa
# 43                  CHL                   152    Americas
# 44                  CHN                   156        Asia
# 45                  CXR                   162     Oceania
# 46                  CCK                   166     Oceania
# 47                  COL                   170    Americas
# 48                  COM                   174      Africa
# 49                  COG                   178      Africa
# ..                  ...                   ...         ...
# 196                 SYC                   690      Africa
# 197                 SLE                   694      Africa
# 198                 SGP                   702        Asia
# 199                 SVK                   703      Europe
# 200                 SVN                   705      Europe
# 201                 SLB                    90     Oceania
# 202                 SOM                   706      Africa
# 203                 ZAF                   710      Africa
# 204                 SGS                   239    Americas
# 205                 ESP                   724      Europe
# 206                 LKA                   144        Asia
# 207                 SDN                   736      Africa
# 208                 SUR                   740    Americas
# 209                 SJM                   744      Europe
# 210                 SWZ                   748      Africa
# 211                 SWE                   752      Europe
# 212                 CHE                   756      Europe
# 213                 SYR                   760        Asia
# 214                 TWN                   158         NaN
# 215                 TJK                   762        Asia
# 216                 TZA                   834      Africa
# 217                 THA                   764        Asia
# 218                 TLS                   626        Asia
# 219                 TGO                   768      Africa
# 220                 TKL                   772     Oceania
# 221                 TON                   776     Oceania
# 222                 TTO                   780    Americas
# 223                 TUN                   788      Africa
# 224                 TUR                   792        Asia
# 225                 TKM                   795        Asia
# 226                 TCA                   796    Americas
# 227                 TUV                   798     Oceania
# 228                 UGA                   800      Africa
# 229                 UKR                   804      Europe
# 230                 ARE                   784        Asia
# 231                 GBR                   826      Europe
# 232                 USA                   840    Americas
# 233                 UMI                   581     Oceania
# 234                 URY                   858    Americas
# 235                 UZB                   860        Asia
# 236                 VUT                   548     Oceania
# 237                 VEN                   862    Americas
# 238                 VNM                   704        Asia
# 239                 VGB                    92    Americas
# 240                 VIR                   850    Americas
# 241                 WLF                   876     Oceania
# 242                 ESH                   732      Africa
# 243                 YEM                   887        Asia
# 244                 ZMB                   894      Africa
# 245                 ZWE                   716      Africa
#
#                      Sub-region Name Developed / Developing Countries
# 0                      Southern Asia                  Least Developed
# 1                    Northern Europe                        Developed
# 2                    Southern Europe                        Developed
# 3                    Northern Africa                       Developing
# 4                          Polynesia                       Developing
# 5                    Southern Europe                        Developed
# 6                 Sub-Saharan Africa                  Least Developed
# 7    Latin America and the Caribbean                       Developing
# 8                                NaN                              NaN
# 9    Latin America and the Caribbean                       Developing
# 237  Latin America and the Caribbean                       Developing
# 238               South-eastern Asia                       Developing
# 239  Latin America and the Caribbean                       Developing
# 240  Latin America and the Caribbean                       Developing
# 241                        Polynesia                       Developing
# 242                  Northern Africa                       Developing
# 243                     Western Asia                  Least Developed
# 244               Sub-Saharan Africa                  Least Developed
# 245               Sub-Saharan Africa                       Developing
#
# [246 rows x 7 columns]

# %%
df_iso.rename(columns={'Country name': 'passportfrom_Country_name'}, inplace=True)
df_pivot_flattened = pd.merge(df_pivot_flattened, df_iso, how='left', on='passportfrom_Country_name')

# %%
df_pivot_flattened['visaFreeRatio'] = round((df_pivot_flattened['visafree'] / df_pivot_flattened['visafreeTO']).astype(float),1)

# %%
# Re-order and format the values
df_pivot_flattened.sort_values('New_Overall_ranking',ascending=True, inplace=True)
df_pivot_flattened = df_pivot_flattened.reset_index(drop=True)
df_pivot_flattened.sample(5).style.format({
    'UN_World_GDP_percent': '{:.2%}'.format,
    'UN_population_Value_2015_percent': '{:.2%}'.format,
    'Surface_area_covered_percent': '{:.2%}'.format,
    'unesco_total_sites_percent': '{:.2%}'.format
    })
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_36e7d56e_2504_11e9_acfb_c99692cd9cac" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >passportfrom_Country_name</th>
#         <th class="col_heading level0 col1" >Surface_area_covered_percent</th>
#         <th class="col_heading level0 col2" >UN_World_GDP_percent</th>
#         <th class="col_heading level0 col3" >UN_population_Value_2015_percent</th>
#         <th class="col_heading level0 col4" >countryto_Surface_area</th>
#         <th class="col_heading level0 col5" >countryto_UN_GDP_currentPrices2016</th>
#         <th class="col_heading level0 col6" >countryto_UN_population_Value_2015_millions</th>
#         <th class="col_heading level0 col7" >unesco_total_sites</th>
#         <th class="col_heading level0 col8" >unesco_total_sites_percent</th>
#         <th class="col_heading level0 col9" >visafree</th>
#         <th class="col_heading level0 col10" >visafreeTO</th>
#         <th class="col_heading level0 col11" >Surface_Rank</th>
#         <th class="col_heading level0 col12" >GDP_Rank</th>
#         <th class="col_heading level0 col13" >Population_Rank</th>
#         <th class="col_heading level0 col14" >visafree_countries_Rank</th>
#         <th class="col_heading level0 col15" >unesco_total_sites_Rank</th>
#         <th class="col_heading level0 col16" >Overall_ranking_calculation</th>
#         <th class="col_heading level0 col17" >New_Overall_ranking</th>
#         <th class="col_heading level0 col18" >country_alpha_2code</th>
#         <th class="col_heading level0 col19" >country_alpha_3code</th>
#         <th class="col_heading level0 col20" >country_numeric_code</th>
#         <th class="col_heading level0 col21" >Region Name</th>
#         <th class="col_heading level0 col22" >Sub-region Name</th>
#         <th class="col_heading level0 col23" >Developed / Developing Countries</th>
#         <th class="col_heading level0 col24" >visaFreeRatio</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_36e7d56e_2504_11e9_acfb_c99692cd9caclevel0_row0" class="row_heading level0 row0" >154</th>
#         <td id="T_36e7d56e_2504_11e9_acfb_c99692cd9cacrow0_col0" class="data row0 col0" >Sao Tome and Principe</td>
#         <td id="T_36e7d56e_2504_11e9_acfb_c99692cd9cacrow0_col1" class="data row0 col1" >10.90%</td>
#         <td id="T_36e7d56e_2504_11e9_acfb_c99692cd9cacrow0_col2" class="data row0 col2" >5.30%</td>
#         <td id="T_36e7d56e_2504_11e9_acfb_c99692cd9cacrow0_col3" class="data row0 col3" >16.90%</td>
#         <td id="T_36e7d56e_2504_11e9_acfb_c99692cd9cacrow0_col4" class="data row0 col4" >14835</td>
#         <td id="T_36e7d56e_2504_11e9_acfb_c99692cd9cacrow0_col5" class="data row0 col5" >4011.44</td>
#         <td id="T_36e7d56e_2504_11e9_acfb_c99692cd9cacrow0_col6" class="data row0 col6" >1247.72</td>
#         <td id="T_36e7d56e_2504_11e9_acfb_c99692cd9cacrow0_col7" class="data row0 col7" >151</td>
#         <td id="T_36e7d56e_2504_11e9_acfb_c99692cd9cacrow0_col8" class="data row0 col8" >12.95%</td>
#         <td id="T_36e7d56e_2504_11e9_acfb_c99692cd9cacrow0_col9" class="data row0 col9" >59</td>
#         <td id="T_36e7d56e_2504_11e9_acfb_c99692cd9cacrow0_col10" class="data row0 col10" >57</td>
#         <td id="T_36e7d56e_2504_11e9_acfb_c99692cd9cacrow0_col11" class="data row0 col11" >166</td>
#         <td id="T_36e7d56e_2504_11e9_acfb_c99692cd9cacrow0_col12" class="data row0 col12" >142</td>
#         <td id="T_36e7d56e_2504_11e9_acfb_c99692cd9cacrow0_col13" class="data row0 col13" >149</td>
#         <td id="T_36e7d56e_2504_11e9_acfb_c99692cd9cacrow0_col14" class="data row0 col14" >143</td>
#         <td id="T_36e7d56e_2504_11e9_acfb_c99692cd9cacrow0_col15" class="data row0 col15" >150</td>
#         <td id="T_36e7d56e_2504_11e9_acfb_c99692cd9cacrow0_col16" class="data row0 col16" >750</td>
#         <td id="T_36e7d56e_2504_11e9_acfb_c99692cd9cacrow0_col17" class="data row0 col17" >155</td>
#         <td id="T_36e7d56e_2504_11e9_acfb_c99692cd9cacrow0_col18" class="data row0 col18" >ST</td>
#         <td id="T_36e7d56e_2504_11e9_acfb_c99692cd9cacrow0_col19" class="data row0 col19" >STP</td>
#         <td id="T_36e7d56e_2504_11e9_acfb_c99692cd9cacrow0_col20" class="data row0 col20" >678</td>
#         <td id="T_36e7d56e_2504_11e9_acfb_c99692cd9cacrow0_col21" class="data row0 col21" >Africa</td>
#         <td id="T_36e7d56e_2504_11e9_acfb_c99692cd9cacrow0_col22" class="data row0 col22" >Sub-Saharan Africa</td>
#         <td id="T_36e7d56e_2504_11e9_acfb_c99692cd9cacrow0_col23" class="data row0 col23" >Least Developed</td>
#         <td id="T_36e7d56e_2504_11e9_acfb_c99692cd9cacrow0_col24" class="data row0 col24" >1</td>
#     </tr>    <tr>
#         <th id="T_36e7d56e_2504_11e9_acfb_c99692cd9caclevel0_row1" class="row_heading level0 row1" >126</th>
#         <td id="T_36e7d56e_2504_11e9_acfb_c99692cd9cacrow1_col0" class="data row1 col0" >Botswana</td>
#         <td id="T_36e7d56e_2504_11e9_acfb_c99692cd9cacrow1_col1" class="data row1 col1" >13.18%</td>
#         <td id="T_36e7d56e_2504_11e9_acfb_c99692cd9cacrow1_col2" class="data row1 col2" >9.78%</td>
#         <td id="T_36e7d56e_2504_11e9_acfb_c99692cd9cacrow1_col3" class="data row1 col3" >17.59%</td>
#         <td id="T_36e7d56e_2504_11e9_acfb_c99692cd9cacrow1_col4" class="data row1 col4" >17946</td>
#         <td id="T_36e7d56e_2504_11e9_acfb_c99692cd9cacrow1_col5" class="data row1 col5" >7397</td>
#         <td id="T_36e7d56e_2504_11e9_acfb_c99692cd9cacrow1_col6" class="data row1 col6" >1298.9</td>
#         <td id="T_36e7d56e_2504_11e9_acfb_c99692cd9cacrow1_col7" class="data row1 col7" >205</td>
#         <td id="T_36e7d56e_2504_11e9_acfb_c99692cd9cacrow1_col8" class="data row1 col8" >17.58%</td>
#         <td id="T_36e7d56e_2504_11e9_acfb_c99692cd9cacrow1_col9" class="data row1 col9" >83</td>
#         <td id="T_36e7d56e_2504_11e9_acfb_c99692cd9cacrow1_col10" class="data row1 col10" >105</td>
#         <td id="T_36e7d56e_2504_11e9_acfb_c99692cd9cacrow1_col11" class="data row1 col11" >143</td>
#         <td id="T_36e7d56e_2504_11e9_acfb_c99692cd9cacrow1_col12" class="data row1 col12" >122</td>
#         <td id="T_36e7d56e_2504_11e9_acfb_c99692cd9cacrow1_col13" class="data row1 col13" >140</td>
#         <td id="T_36e7d56e_2504_11e9_acfb_c99692cd9cacrow1_col14" class="data row1 col14" >108</td>
#         <td id="T_36e7d56e_2504_11e9_acfb_c99692cd9cacrow1_col15" class="data row1 col15" >128</td>
#         <td id="T_36e7d56e_2504_11e9_acfb_c99692cd9cacrow1_col16" class="data row1 col16" >641</td>
#         <td id="T_36e7d56e_2504_11e9_acfb_c99692cd9cacrow1_col17" class="data row1 col17" >127</td>
#         <td id="T_36e7d56e_2504_11e9_acfb_c99692cd9cacrow1_col18" class="data row1 col18" >BW</td>
#         <td id="T_36e7d56e_2504_11e9_acfb_c99692cd9cacrow1_col19" class="data row1 col19" >BWA</td>
#         <td id="T_36e7d56e_2504_11e9_acfb_c99692cd9cacrow1_col20" class="data row1 col20" >72</td>
#         <td id="T_36e7d56e_2504_11e9_acfb_c99692cd9cacrow1_col21" class="data row1 col21" >Africa</td>
#         <td id="T_36e7d56e_2504_11e9_acfb_c99692cd9cacrow1_col22" class="data row1 col22" >Sub-Saharan Africa</td>
#         <td id="T_36e7d56e_2504_11e9_acfb_c99692cd9cacrow1_col23" class="data row1 col23" >Developing</td>
#         <td id="T_36e7d56e_2504_11e9_acfb_c99692cd9cacrow1_col24" class="data row1 col24" >0.8</td>
#     </tr>    <tr>
#         <th id="T_36e7d56e_2504_11e9_acfb_c99692cd9caclevel0_row2" class="row_heading level0 row2" >77</th>
#         <td id="T_36e7d56e_2504_11e9_acfb_c99692cd9cacrow2_col0" class="data row2 col0" >Belarus</td>
#         <td id="T_36e7d56e_2504_11e9_acfb_c99692cd9cacrow2_col1" class="data row2 col1" >45.13%</td>
#         <td id="T_36e7d56e_2504_11e9_acfb_c99692cd9cacrow2_col2" class="data row2 col2" >26.99%</td>
#         <td id="T_36e7d56e_2504_11e9_acfb_c99692cd9cacrow2_col3" class="data row2 col3" >43.35%</td>
#         <td id="T_36e7d56e_2504_11e9_acfb_c99692cd9cacrow2_col4" class="data row2 co

# %% [markdown]
# ## The average passport rank by continent and sub-region

# %%
df_pivot_flattened.rename(columns={'Sub-region Name': 'passportfrom_Sub-region_Name'}, inplace=True)
df_pivot_flattened.rename(columns={'Region Name': 'passportfrom_Region_Name'}, inplace=True)
df_pivot_flattened.rename(columns={'Developed / Developing Countries': 'passportfrom_Developed_Developing_Countries'}, inplace=True)

# %%
df_pivot_flattened_continent = df_pivot_flattened.groupby(by="passportfrom_Region_Name")
df_pivot_flattened_subRegion = df_pivot_flattened.groupby(by="passportfrom_Sub-region_Name")

# %%
# Median passport rank by continent
df_pivot_flattened_continent['New_Overall_ranking'].median().sort_values()
# Out:
# passportfrom_Region_Name
# Europe       28.5
# Americas     70.0
# Oceania      85.0
# Asia        120.5
# Africa      156.0
# Name: New_Overall_ranking, dtype: float64

# %%
# Standard deviation by continent
df_pivot_flattened_continent = df_pivot_flattened.groupby(by="passportfrom_Region_Name")
df_pivot_flattened_continent['New_Overall_ranking'].std().sort_values()
# Out:
# passportfrom_Region_Name
# Oceania     26.363478
# Europe      27.204835
# Americas    28.576802
# Africa      29.763143
# Asia        55.925110
# Name: New_Overall_ranking, dtype: float64

# %%
# Ratio countries welcomed vs countries welcoming by sub-region
df_pivot_flattened_subRegion = df_pivot_flattened.groupby(by="passportfrom_Sub-region_Name")
df_pivot_flattened_subRegion['visaFreeRatio'].mean().sort_values()
# Out:
# passportfrom_Sub-region_Name
# Polynesia                          1.000000
# South-eastern Asia                 1.190909
# Melanesia                          1.200000
# Latin America and the Caribbean    1.366667
# Southern Europe                    1.700000
# Eastern Europe                     1.770000
# Western Europe                     1.977778
# Northern Europe                    1.990000
# Micronesia                         2.000000
# Sub-Saharan Africa                 2.025532
# Western Asia                       2.866667
# Northern America                   3.850000
# Australia and New Zealand          4.050000
# Northern Africa                    4.400000
# Central Asia                       6.560000
# Southern Asia                      7.144444
# Eastern Asia                       8.028571
# Name: visaFreeRatio, dtype: float64

# %%
# country access by sub-region
df_pivot_flattened_subRegion_access = df_pivot_flattened_subRegion[['visafree','visafreeTO']].mean().astype(int)
df_pivot_flattened_subRegion_access['visaFreeRatio2'] = round(df_pivot_flattened_subRegion['visafree'].mean() / df_pivot_flattened_subRegion['visafreeTO'].mean().astype(float),1)
df_pivot_flattened_subRegion_access.sort_values('visaFreeRatio2',ascending=False)
# Out:
#                                  visafree  visafreeTO  visaFreeRatio2
# passportfrom_Sub-region_Name
# Australia and New Zealand             182          48             3.8
# Northern America                      185          49             3.8
# Northern Europe                       184          92             2.0
# Western Europe                        184          94             2.0
# Eastern Europe                        151          87             1.7
# Southern Europe                       158          93             1.7
# Eastern Asia                          125          79             1.6
# Central Asia                           62          49             1.3
# Latin America and the Caribbean       129         111             1.2
# Melanesia                             108          94             1.2
# Western Asia                           83          71             1.2
# Micronesia                            115         115             1.0
# Northern Africa                        52          50             1.0
# Polynesia                             127         156             0.8
# South-eastern Asia                     96         127             0.8
# Sub-Saharan Africa                     62         100             0.6
# Southern Asia                          48         103             0.5

# %%
# Median passport rank by sub-region
df_pivot_flattened_subRegion = df_pivot_flattened.groupby(by="passportfrom_Sub-region_Name")
df_pivot_flattened_subRegion['New_Overall_ranking'].median().astype(int).sort_values()
# Out:
# passportfrom_Sub-region_Name
# Western Europe                      18
# Northern Europe                     22
# Australia and New Zealand           33
# Southern Europe                     36
# Northern America                    39
# Eastern Europe                      53
# Eastern Asia                        60
# Latin America and the Caribbean     72
# Polynesia                           83
# Micronesia                          87
# Melanesia                           91
# South-eastern Asia                 116
# Western Asia                       119
# Central Asia                       130
# Sub-Saharan Africa                 155
# Northern Africa                    167
# Southern Asia                      181
# Name: New_Overall_ranking, dtype: int32

# %% [markdown]
# ## Rank by sub-regions

# %%
df_pivot_flattened['ranking_bySubRegion'] = df_pivot_flattened.groupby('passportfrom_Sub-region_Name')['Overall_ranking_calculation'].rank(method='min', ascending=True).astype(int)

# %%
df_pivot_flattened.head(5).sort_values(['passportfrom_Sub-region_Name','ranking_bySubRegion'], ascending=[True,True])
# Out:
#   passportfrom_Country_name  Surface_area_covered_percent  \
# 0                     Japan                      0.636426
# 2        Korea, Republic of                      0.737394
# 1                 Singapore                      0.668116
# 3                    France                      0.589313
# 4                   Germany                      0.597502
#
#    UN_World_GDP_percent  UN_population_Value_2015_percent  \
# 0              0.921710                          0.802333
# 2              0.813333                          0.660625
# 1              0.913151                          0.643647
# 3              0.765937                          0.457618
# 4              0.765189                          0.453826
#
#    countryto_Surface_area  countryto_UN_GDP_currentPrices2016  \
# 0                 86657.0                           69726.300
# 2                100405.0                           61527.752
# 1                 90972.0                           69078.830
# 3                 80242.0                           57942.279
# 4                 81357.0                           57885.660
#
#    countryto_UN_population_Value_2015_millions  unesco_total_sites  \
# 0                                      5923.63              1024.0
# 2                                      4877.40              1017.0
# 1                                      4752.05              1009.0
# 3                                      3378.60               951.0
# 4                                      3350.60               951.0
#
#    unesco_total_sites_percent  visafree  visafreeTO  Surface_Rank  GDP_Rank  \
# 0                    0.878216       191          68             4         1
# 2                    0.872213       190         111             1         6
# 1                    0.865352       190         164             2         2
# 3                    0.815609       189          94             9         7
# 4                    0.815609       189          94             8         8
#
#    Population_Rank  visafree_countries_Rank  unesco_total_sites_Rank  \
# 0                1                        1                        1
# 2                2                        2                        2
# 1                3                        2                        3
# 3               16                        4                        5
# 4               17                        4                        5
#
#    Overall_ranking_calculation  New_Overall_ranking country_alpha_2code  \
# 0                            8                    1                  JP
# 2                           13                    3                  KR
# 1                           12                    2                  SG
# 3                           41                    4                  FR
# 4                           42                    5                  DE
#
#   country_alpha_3code  country_numeric_code passportfrom_Region_Name  \
# 0                 JPN                   392                     Asia
# 2                 KOR                   410                     Asia
# 1                 SGP                   702                     Asia
# 3                 FRA                   250                   Europe
# 4                 DEU                   276                   Europe
#
#   passportfrom_Sub-region_Name passportfrom_Developed_Developing_Countries  \
# 0                 Eastern Asia                                   Developed
# 2                 Eastern Asia                                  Developing
# 1           South-eastern Asia                                  Developing
# 3               Western Europe                                   Developed
# 4               Western Europe                                   Developed
#
#    visaFreeRatio  ranking_bySubRegion
# 0            2.8                    1
# 2            1.7                    2
# 1            1.2                    1
# 3            2.0                    1
# 4            2.0                    2

# %% [markdown]
# ## Create a new column Gain/loss in ranking

# %%
df_pivot_flattened['gain-loss'] = df_pivot_flattened['visafree_countries_Rank'] - df_pivot_flattened['New_Overall_ranking']

# %%
df_pivot_flattened.sample(5)
# Out:
#     passportfrom_Country_name  Surface_area_covered_percent  \
# 97               South Africa                      0.387906
# 94                      Qatar                      0.214583
# 70                      Tonga                      0.254329
# 121              Saudi Arabia                      0.142352
# 146                     Nepal                      0.106726
#
#      UN_World_GDP_percent  UN_population_Value_2015_percent  \
# 97               0.149619                          0.252011
# 94               0.286151                          0.406476
# 70               0.467029                          0.450266
# 121              0.096370                          0.198143
# 146              0.065901                          0.335572
#
#      countryto_Surface_area  countryto_UN_GDP_currentPrices2016  \
# 97                  52818.0                           11318.519
# 94                  29218.0                           21646.962
# 70                  34630.0                           35330.250
# 121                 19383.0                            7290.287
# 146                 14532.0                            4985.300
#
#      countryto_UN_population_Value_2015_millions  unesco_total_sites  \
# 97                                       1860.60               320.0
# 94                                       3001.02               346.0
# 70                                       3324.32               693.0
# 121                                      1462.89               221.0
# 146                                      2477.53               136.0
#
#      unesco_total_sites_percent  visafree  visafreeTO  Surface_Rank  GDP_Rank  \
# 97                     0.274443       102          77            78       106
# 94                     0.296741        86          94           114        95
# 70                     0.594340       125          70           104        63
# 121                    0.189537        74           5           131       123
# 146                    0.116638        41         187           168       135
#
#      Population_Rank  visafree_countries_Rank  unesco_total_sites_Rank  \
# 97               104                       96                      102
# 94                51                      105                      100
# 70                22                       84                       85
# 121              123                      119                      123
# 146               74                      188                      166
#
#      Overall_ranking_calculation  New_Overall_ranking country_alpha_2code  \
# 97                           486                   98                  ZA
# 94                           465                   95                  QA
# 70                           358                   71                  TO
# 121                          619                  121                  SA
# 146                          731                  147                  NP
#
#     country_alpha_3code  country_numeric_code passportfrom_Region_Name  \
# 97                  ZAF                   710                   Africa
# 94                  QAT                   634                     Asia
# 70                  TON                   776                  Oceania
# 121                 SAU                   682                     Asia
# 146                 NPL                   524                     Asia
#
#     passportfrom_Sub-region_Name passportfrom_Developed_Developing_Countries  \
# 97            Sub-Saharan Africa                                  Developing
# 94                  Western Asia                                  Developing
# 70                     Polynesia                                  Developing
# 121                 Western Asia                                  Developing
# 146                Southern Asia                             Least Developed
#
#      visaFreeRatio  ranking_bySubRegion  gain-loss
# 97             1.3                    3         -2
# 94             0.9                    5         10
# 70             1.8                    1         13
# 121           14.8                   11         -2
# 146            0.2                    3         41

# %% [markdown]
# ## Reorder the columns

# %%
df_final = df_pivot_flattened[['passportfrom_Country_name',
                                         'country_alpha_3code',
                                         'New_Overall_ranking',
                                         'gain-loss',
                                         'visafree',
                                         'visafree_countries_Rank',
                                         'countryto_UN_GDP_currentPrices2016',
                                         'GDP_Rank',
                                         'UN_World_GDP_percent',
                                         'countryto_UN_population_Value_2015_millions',
                                         'Population_Rank',
                                         'UN_population_Value_2015_percent',
                                         'countryto_Surface_area',
                                         'Surface_Rank',
                                         'Surface_area_covered_percent',
                                         'unesco_total_sites',
                                         'unesco_total_sites_percent',
                                         'unesco_total_sites_Rank',
                                         'Overall_ranking_calculation',
                                         'passportfrom_Region_Name',
                                         'passportfrom_Sub-region_Name',
                                         'passportfrom_Developed_Developing_Countries',
                                         'visafreeTO',
                                         'visaFreeRatio',
                                         'ranking_bySubRegion']]

# %%
# Export to CSV
df_final.to_csv('ranking.csv')

# %% [markdown]
# ## Biggest winners and losers

# %%
df_rankgainloss = df_pivot_flattened[['passportfrom_Country_name','gain-loss']].sort_values('gain-loss', ascending=False, inplace=False)
df_rankgainloss.head(5).style.format({
    'UN_World_GDP_percent': '{:.2%}'.format,
    'UN_population_Value_2015_percent': '{:.2%}'.format,
    'Surface_area_covered_percent': '{:.2%}'.format,
    'unesco_total_sites_percent': '{:.2%}'.format
    })
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_3741ce62_2504_11e9_9c0d_c99692cd9cac" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >passportfrom_Country_name</th>
#         <th class="col_heading level0 col1" >gain-loss</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T
#         <td id="T_37466192_2504_11e9_9dbc_c99692cd9cacrow2_col1" class="data row2 col1" >-28</td>
#     </tr>    <tr>
#         <th id="T_37466192_2504_11e9_9dbc_c99692cd9caclevel0_row3" class="row_heading level0 row3" >163</th>
#         <td id="T_37466192_2504_11e9_9dbc_c99692cd9cacrow3_col0" class="data row3 col0" >Uganda</td>
#         <td id="T_37466192_2504_11e9_9dbc_c99692cd9cacrow3_col1" class="data row3 col1" >-31</td>
#     </tr>    <tr>
#         <th id="T_37466192_2504_11e9_9dbc_c99692cd9caclevel0_row4" class="row_heading level0 row4" >171</th>
#         <td id="T_37466192_2504_11e9_9dbc_c99692cd9cacrow4_col0" class="data row4 col0" >Sierra Leone</td>
#         <td id="T_37466192_2504_11e9_9dbc_c99692cd9cacrow4_col1" class="data row4 col1" >-33</td>
#     </tr></tbody>
# </table>

# %% [markdown]
# # A little program to access the results easily

# %%
# create a new list
countrylist = list(set(df_final['passportfrom_Country_name'].drop_duplicates().values.tolist()))
countrylist.sort()

# %%
# Select the passport holder's country with drop drop menu
countryselected = widgets.Dropdown(
    options=countrylist,
    value='Hong Kong',
    description="Country:",
    disabled=False)

def on_change(change):
    if change['type'] == 'change' and change['name'] == 'value':
        print ("Country selected: %s" % change['new'])

countryselected.observe(on_change)
display(countryselected)
# Out:
# Dropdown(description='Country:', index=74, options=('Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola', …

# %%
# the number of destinations accessible visa-free
countryselectedvisafree = df_final[df_final['passportfrom_Country_name'] == countryselected.value]['visafree']
countryselectedvisafree = countryselectedvisafree.to_frame()
countryselectedvisafree = countryselectedvisafree.iloc[0]['visafree']
# the overall country rank
countryrank = df_final[df_final['passportfrom_Country_name'] == countryselected.value]['New_Overall_ranking']
countryrank = countryrank.to_frame()
countryrank = countryrank.iloc[0]['New_Overall_ranking']
# the gain-loss compare the to Henley Passport Index 
gainloss = df_final[df_final['passportfrom_Country_name'] == countryselected.value]['gain-loss']
gainloss = gainloss.to_frame()
gainloss = gainloss.iloc[0]['gain-loss']
# the rank regarding the number of countries accessible visa-free
visafreecountriesRank = df_final[df_final['passportfrom_Country_name'] == countryselected.value]['visafree_countries_Rank']
visafreecountriesRank = visafreecountriesRank.to_frame()
visafreecountriesRank = visafreecountriesRank.iloc[0]['visafree_countries_Rank']
# the rank regarding to the population accessible visa-free
countryselectedpopulation = df_final[df_final['passportfrom_Country_name'] == countryselected.value]['UN_population_Value_2015_percent']
countryselectedpopulation = countryselectedpopulation.to_frame()
countryselectedpopulation = countryselectedpopulation.iloc[0]['UN_population_Value_2015_percent']
# the rank regarding to the globe surface accessible visa-free
countryselectedsurface = df_final[df_final['passportfrom_Country_name'] == countryselected.value]['Surface_area_covered_percent']
countryselectedsurface = countryselectedsurface.to_frame()
countryselectedsurface = countryselectedsurface.iloc[0]['Surface_area_covered_percent']
countryselectedsurface = countryselectedsurface.item()
# the rank regarding to the world GDP accessible visa-free
countryselectedGDP = df_final[df_final['passportfrom_Country_name'] == countryselected.value]['UN_World_GDP_percent']
countryselectedGDP = countryselectedGDP.to_frame()
countryselectedGDP = countryselectedGDP.iloc[0]['UN_World_GDP_percent']
# the rank regarding to the number of unesco sites accessible visa-free
countryselectedUnesco = df_final[df_final['passportfrom_Country_name'] == countryselected.value]['unesco_total_sites_percent']
countryselectedUnesco = countryselectedUnesco.to_frame()
countryselectedUnesco = countryselectedUnesco.iloc[0]['unesco_total_sites_percent']

# Run this query to get the statistics
def country_access(countryselected,countryselectedvisafree,countryrank,visafreecountriesRank,gainloss,countryselectedpopulation,countryselectedsurface,countryselectedGDP,countryselectedUnesco):
    print(countryselected.value + "'s passport gives you access to:")
    print("\n" + str(countryselectedvisafree) + " destinations visa-free (over " + str(df_visa_free['countryto_alpha_2code'].nunique()) + " possible), covering:")
    print("\t" + "{:.0%}".format(countryselectedpopulation) + " of the world's population")
    print("\t" + "{:.0%}".format(countryselectedsurface) + " of the world's surface")
    print("\t" + "{:.0%}".format(countryselectedGDP) + " of the world's GPD")
    print("\t" + "{:.0%}".format(countryselectedUnesco) + " of the world's Unesco World heritage sites")
    print("\nIt ranks " + str(countryrank)  +  " over " + str(df_final['passportfrom_Country_name'].nunique()) + " countries' passports according to these 5 criteria.")
    print("It's a " + str(np.where(gainloss < 0, "rank loss of "+str(gainloss), "rank gain of +" + str(gainloss))) + " compare to the traditional Henley Passport Index (ranked " + str(visafreecountriesRank) + ").")
country_access(countryselected,countryselectedvisafree,countryrank,visafreecountriesRank,gainloss,countryselectedpopulation,countryselectedsurface,countryselectedGDP,countryselectedUnesco)
# Out:
# Hong Kong's passport gives you access to:
#
# 170 destinations visa-free (over 226 possible), covering:
# 	40% of the world's population
# 	65% of the world's surface
# 	53% of the world's GPD
# 	79% of the world's Unesco World heritage sites
#
# It ranks 34 over 197 countries' passports according to these 5 criteria.
# It's a rank gain of +8 compare to the traditional Henley Passport Index (ranked 42).

# %% [markdown]
# ## Seaborn visualization
# Correlation between countries accessible visa-free and countries welcomes visa-free

# %%
df_final.head(10)
# Out:
#   passportfrom_Country_name country_alpha_3code  New_Overall_ranking  \
# 0                     Japan                 JPN                    1
# 1                 Singapore                 SGP                    2
# 2        Korea, Republic of                 KOR                    3
# 3                    France                 FRA                    4
# 4                   Germany                 DEU                    5
# 5                   Denmark                 DNK                    6
# 6                   Finland                 FIN                    6
# 7                    Sweden                 SWE                    6
# 8                     Italy                 ITA                    6
# 9                San Marino                 SMR                   10
#
#    gain-loss  visafree  visafree_countries_Rank  \
# 0          0       191                        1
# 1          0       190                        2
# 2         -1       190                        2
# 3          0       189                        4
# 4         -1       189                        4
# 5          0       188                        6
# 6          0       188                        6
# 7          0       188                        6
# 8          0       188                        6
# 9         36       169                       46
#
#    countryto_UN_GDP_currentPrices2016  GDP_Rank  UN_World_GDP_percent  \
# 0                           69726.300         1              0.921710
# 1                           69078.830         2              0.913151
# 2                           61527.752         6              0.813333
# 3                           57942.279         7              0.765937
# 4                           57885.660         8              0.765189
# 5                           57874.500         9              0.765041
# 6                           57874.500         9              0.765041
# 7                           57874.500         9              0.765041
# 8                           57874.500         9              0.765041
# 9                           68521.709         3              0.905786
#
#    countryto_UN_population_Value_2015_millions  Population_Rank  \
# 0                                      5923.63                1
# 1                                      4752.05                3
# 2                                      4877.40                2
# 3                                      3378.60               16
# 4                                      3350.60               17
# 5                                      3347.62               18
# 6                                      3347.62               18
# 7                                      3347.62               18
# 8                                      3347.62               18
# 9                                      4481.94                4
#
#    UN_population_Value_2015_percent  countryto_Surface_area  Surface_Rank  \
# 0                          0.802333                 86657.0             4
# 1                          0.643647                 90972.0             2
# 2                          0.660625                100405.0             1
# 3                          0.457618                 80242.0             9
# 4                          0.453826                 81357.0             8
# 5                          0.453422                 79793.0            10
# 6                          0.453422                 79793.0            10
# 7                          0.453422                 79793.0            10
# 8                          0.453422                 79793.0            10
# 9                          0.607061                 82795.0             7
#
#    Surface_area_covered_percent  unesco_total_sites  \
# 0                      0.636426              1024.0
# 1                      0.668116              1009.0
# 2                      0.737394              1017.0
# 3                      0.589313               951.0
# 4                      0.597502               951.0
# 5                      0.586015               946.0
# 6                      0.586015               946.0
# 7                      0.586015               946.0
# 8                      0.586015               946.0
# 9                      0.608062               959.0
#
#    unesco_total_sites_percent  unesco_total_sites_Rank  \
# 0                    0.878216                        1
# 1                    0.865352                        3
# 2                    0.872213                        2
# 3                    0.815609                        5
# 4                    0.815609                        5
# 5                    0.811321                        7
# 6                    0.811321                        7
# 7                    0.811321                        7
# 8                    0.811321                        7
# 9                    0.822470                        4
#
#    Overall_ranking_calculation passportfrom_Region_Name  \
# 0                            8                     Asia
# 1                           12                     Asia
# 2                           13                     Asia
# 3                           41                   Europe
# 4                           42                   Europe
# 5                           50                   Europe
# 6                           50                   Europe
# 7                           50                   Europe
# 8                           50                   Europe
# 9                           64                   Europe
#
#   passportfrom_Sub-region_Name passportfrom_Developed_Developing_Countries  \
# 0                 Eastern Asia                                   Developed
# 1           South-eastern Asia                                  Developing
# 2                 Eastern Asia                                  Developing
# 3               Western Europe                                   Developed
# 4               Western Europe                                   Developed
# 5              Northern Europe                                   Developed
# 6              Northern Europe                                   Developed
# 7              Northern Europe                                   Developed
# 8              Southern Europe                                   Developed
# 9              Southern Europe                                   Developed
#
#    visafreeTO  visaFreeRatio  ranking_bySubRegion
# 0          68            2.8                    1
# 1         164            1.2                    1
# 2         111            1.7                    2
# 3          94            2.0                    1
# 4          94            2.0                    2
# 5          94            2.0                    1
# 6          94            2.0                    1
# 7          94            2.0                    1
# 8          94            2.0                    1
# 9          94            1.8                    2

# %%
sns.set()

# Plot sepal with as a function of sepal_length across days
g = sns.lmplot(x="visafree", y="visafreeTO", hue="passportfrom_Developed_Developing_Countries",
               truncate=True, height=5, data=df_final)

# Use more informative axis labels than are provided by default
g.set_axis_labels("# of accessible countries", "# of welcomed countries")
# Out:
# C:\Users\Jrmy\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning:
#
# Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.

# %% [markdown]
# ## Correlation between sub-region and visa free

# %%
sns.set(style="ticks")

# Show the results of a linear regression within each dataset
g = sns.lmplot(x="visafree", y="visafreeTO", col="passportfrom_Sub-region_Name", hue="passportfrom_Sub-region_Name", data=df_final,
               sharex=False,sharey=False,
               col_wrap=3,
               #ci=None, 
               #palette="muted",
               height=4,
               scatter_kws={"s": 50, "alpha": 1}
              )

# control x and y limits
g.set(ylim=(0, 200))
g.set(xlim=(0, 230))

# Use more informative axis labels than are provided by default
g.set_axis_labels("# of accessible countries", "# of welcomed countries")

# %% [markdown]
# ## Heatmap of the new passport ranking

# %%
data = [ dict(
        type = 'choropleth',
        locations = df_final['country_alpha_3code'],
        z = df_final['New_Overall_ranking'],
        text = "<br />" + df_final['passportfrom_Country_name'] + "'s passport gives you access to"
                + "<br />" + df_final['visafree'].astype(int).astype(str) + " destinations visa-free (over " + str(df_visa_free['countryto_alpha_2code'].nunique()) + " possible)"
                + "<br /><br />" + "It ranks " +  df_final['New_Overall_ranking'].astype(int).astype(str) + " th overall, " + df_final['ranking_bySubRegion'].astype(int).astype(str) + " th in " + df_final['passportfrom_Sub-region_Name'] 
                + "<br /><br />That's a visa-free coverage of:"
                + "<br />" + (df_final['UN_World_GDP_percent'].astype(float)*100).astype(int).astype(str) + " % of the world's GDP"  
                + "<br />" + (df_final['UN_population_Value_2015_percent'].astype(float)*100).astype(int).astype(str) + " % of the world's population"
                + "<br />" + (df_final['Surface_area_covered_percent'].astype(float)*100).astype(int).astype(str) +  " % of the earth's land surface"
                + "<br />" + (df_final['unesco_total_sites_percent'].astype(float)*100).astype(int).astype(str) + " % of the Unesco's heritage sites"
                + "<br /><br />In " + df_final['passportfrom_Country_name'] + ", " + df_final['visafreeTO'].astype(int).astype(str) + " citizenships are welcomed visa-free"
                + "<br />" + "That's a ratio of " + df_final['visaFreeRatio'].astype(str),
        autocolorscale = True,
        reversescale = True,
        marker = dict(
            line = dict (
                color = 'rgb(180,180,180)',
                width = 0.5
            ) ),
        colorbar = dict(
            tickmode = 'array',
            tickvals = [180,100,20],
            ticktext = ['Weak','Medium','Strong'],
            autotick = False,
            #tickprefix = 'test',
            title = 'Passport rank. 1 = best'),
      ) ]

layout = dict(
    title = 'Passport rank heatmap',
    geo = dict(
        showframe = True,
        showcoastlines = True,
        projection = dict(
            type = 'Mercator'
        )
    )
)

fig = dict( data=data, layout=layout )
py.iplot( fig, validate=False, filename='passports-world-map1' )
# Out:
# C:\Users\Jrmy\Anaconda3\lib\site-packages\IPython\core\display.py:689: UserWarning:
#
# Consider using IPython.display.IFrame instead
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~jeremielamboley/4.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# ## Heatmap visualization of the ratio countries accessibles vs countries welcomed visa-free

# %%
data = [ dict(
        type = 'choropleth',
        locations = df_final['country_alpha_3code'],
        z = df_final['visaFreeRatio'],
        text = "<br />" + df_final['passportfrom_Country_name'] + "'s passport gives you access to"
                + "<br />" + df_final['visafree'].astype(int).astype(str) + " destinations"
                + "<br /><br />" + df_final['visafreeTO'].astype(int).astype(str) + " citizenships are welcomed visa-free"
                + "<br /><br />" + "That's a ratio of " + round(df_final['visaFreeRatio'],1).astype(str),
        autocolorscale = False,
        reversescale = False,
        colorscale = [[0, 'rgb(51,160,44,0.5)'], #green
                      [0.05, 'rgb(178,223,138,0.5)'], #light green
                      [0.08, 'rgb(255,255,255,0.5)'], #white
                      [0.12, 'rgb(251,154,153,0.5)'], # salmon
                      [1, 'rgb(227,26,28,0.5)']], #red
        marker = dict(
            line = dict (
                color = 'rgb(180,180,180)',
                width = 0.5
            ) ),
    
        colorbar = dict(
            autotick = False,
            tickmode = 'array',
            #tickprefix = '',
            title = 'Ratio'),
      ) ]



layout = dict(
    title = 'ratio countries accessibles vs countries welcomed visa-free',
    geo = dict(
        showframe = True,
        showcoastlines = True,
        projection = dict(
            type = 'Mercator'
        )
    )
)

fig = dict( data=data, layout=layout )
py.iplot( fig, validate=False, filename='passports-world-map2' )
# Out:
# C:\Users\Jrmy\Anaconda3\lib\site-packages\IPython\core\display.py:689: UserWarning:
#
# Consider using IPython.display.IFrame instead
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~jeremielamboley/2.embed" height="525px" width="100%"></iframe>
