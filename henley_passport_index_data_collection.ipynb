# %%
#import libaries
import requests
from bs4 import BeautifulSoup
import re
import csv
import urllib.request
import json

# %% [markdown]
# ## Test request for the country France

# %% [markdown]
# ### Simple request

# %%
#Make a simple GET request
r = requests.get("https://www.henleypassportindex.com/fetch?url=passports%2FFR%2Fcountries")

# %%
#See what response code the server sent back
r.status_code
# Out:
# 200

# %%
#Check the response’s Content Type
r.headers.get("content-type", "unknown")
# Out:
# 'text/html; charset=UTF-8'

# %%
#Access the full response as JSON
r.json()
# Out:
# [{'id': 1,
#   'name': 'Afghanistan',
#   'code': 'AF',
#   'longitude': None,
#   'latitude': None,
#   'show_map': 0,
#   'created_at': '2017-12-27 12:18:29',
#   'updated_at': '2017-12-27 13:03:43',
#   'deleted_at': None,
#   'region_id': 6,
#   'pivot': {'passport_id': 4,
#    'country_id': 1,
#    'visa_access_id': 2,
#    'is_visa_free': 0},
#   'region': {'id': 6,
#    'name': 'ASIA',
#    'deleted_at': None,
#    'created_at': '2017-12-11 09:52:06',
#    'updated_at': '2017-12-11 09:52:06'}},
#  {'id': 2,
#   'name': 'Albania',
#   'code': 'AL',
#   'longitude': None,
#   'latitude': None,
#   'show_map': 0,
#   'created_at': '2017-12-27 12:18:29',
#   'updated_at': '2017-12-27 13:03:42',
#   'deleted_at': None,
#   'region_id': 5,
#   'pivot': {'passport_id': 4,
#    'country_id': 2,
#    'visa_access_id': 1,
#    'is_visa_free': 1},
#   'region': {'id': 5,
#    'name': 'EUROPE',
#    'deleted_at': None,
#    'created_at': '2017-12-11 09:52:06',
# ...

# %% [markdown]
# ### Complex request

# %%
request_url = "https://www.henleypassportindex.com/fetch?entity=regions&code=FR&url=passports%2FFR%2Fcountries"
#headers = {"accept":"application/json","accept-language":"en-US,en;q=0.9,fr;q=0.8","authorization":"Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiIsImp0aSI6IjRmOWRjYzUzZGI3NTU1MmVlNzkwMmY5YmI3NmE0ZTExOTViYjU4NzYxY2VhM2M2MjhmYWUwOGViYzk1OWI3Y2MyOWNjMzJjMWQ0YWIzMmM4In0.eyJhdWQiOiI0IiwianRpIjoiNGY5ZGNjNTNkYjc1NTUyZWU3OTAyZjliYjc2YTRlMTE5NWJiNTg3NjFjZWEzYzYyOGZhZTA4ZWJjOTU5YjdjYzI5Y2MzMmMxZDRhYjMyYzgiLCJpYXQiOjE1NDcxMDU3MTQsIm5iZiI6MTU0NzEwNTcxNCwiZXhwIjoxNTQ4NDAxNzE0LCJzdWIiOiIxIiwic2NvcGVzIjpbIioiXX0.e9b6fJYLVhz6GELBi-CqZV2oMwVmYptgEloH8ybNf9sFPJUCkAkrOK_qfi5dYqKi7Ey0ajF2eYJACZswqHk1InHIsZSliv5Iz_PqS_6oe5vDZiQSdjOE2ZP_dd9WegfgerLRXgmLBRfmoJEiTUb4Zis6uzTyatg7BOyZ9T9nsUeOdITwIS3vh6z7Y1rTw1RuFAfJbIIt5jveOw7twpz0h8UWKSLN7gpljeJZxfWC35T2SkqEhSCDeXpp1sk1SRThnq9aNZXDOzswWyvzin9d58JcJaTQgwtxiqPWoe6u4YILmovfULKVQZ22QQPfK_fF6-4P9ZdpayTcyXtHNCzUaogo7dSMM9hfVrbdlKAHj9E8QgBuoTrR4GiTE5lVVqvYpL1AD-y6mDduVjJ7xEWGvwy6tl6BMoqBZV_tUirzWCgaQsCdP468XB13QxEzz9C44nmtc69-MkEkyjEVoba9GkC4cRGYkdHVzdIWPEHZ6ZILLUnHl6-N3I4-E5epZ_kb0JAOu60-kKAIBJb9ydHY3pEUTiLjVbXvWc_TLlcYIUkzZ1-8o9ZsfQBNKTKTX4OftkH91g2QTpd4lHONcN4hbZNLhNmvJ8qXbqVl8P6jHoERf4Y5Tv0y1i5vZ1HUoeroI2lt3zA-Ea_Y27qfLvnL3H-YuVb35m-qjJlDa9YBqNQ","x-xsrf-token":"eyJpdiI6ImlzMmNJMDFQSklJOGhxcmUzc2pYckE9PSIsInZhbHVlIjoiQm5wRGQ1VXFzWHp1cUpsU09tWHhxaGxGQmJVWm5KSVVycHhsUVJKc0lPSG01Z2VlMXVLenRVNTlVeW5hT0FIdSIsIm1hYyI6IjQ4MzZiZTcwZDVjYTZkNjJkMDQ2NmI1ZjE4YTc1OGIxYzJiZTQzZTNmNzJmOWNjY2ZhNWE4Y2QyMjM1N2IzMmQifQ=="}
#headers = {'content-type': 'text/html; charset=UTF-8'}
data = {'name': 'value'}

#request = requests.get(request_url, headers = headers, data = data)
r2 = requests.post(request_url, data = data)

# %%
r2.json
# Out:
# <bound method Response.json of <Response [405]>>

# %% [markdown]
# ## Using Regex

# %%
#Using Regular Expressions to look for patterns
# 1 = French people can enter the country visa-fee
# 0 = French people can NOT enter the country visa-fee
re.findall(r'(?i)(?:\[?\{"name":"[\w+\s]*","flags":\[)?\[?\{"id":\d+,"name":"([\w+\(\)\s\-\.\'\;]*)","code":"(\w+)","longitude":null,"latitude":null,"show_map":0,"created_at":"\d+-\d+-\d+ \d+:\d+:\d+","updated_at":"\d+-\d+-\d+ \d+:\d+:\d+","deleted_at":null,"region_id":\d+,"pivot":\{"passport_id":\d+,"country_id":\d+,"visa_access_id":\d+,"is_visa_free":(\d+)},"region":\{"id":\d+,"name":"[\w+\s]*"\,"deleted_at":null,"created_at":"\d+-\d+-\d+ \d+:\d+:\d+"\,"updated_at":"\d+-\d+-\d+ \d+:\d+:\d+"\}\}(?:\]\})?\,?\]?\s*', r.text)
# Out:
# [('Afghanistan', 'AF', '0'),
#  ('Albania', 'AL', '1'),
#  ('Algeria', 'DZ', '0'),
#  ('American Samoa', 'AS', '1'),
#  ('Andorra', 'AD', '1'),
#  ('Angola', 'AO', '0'),
#  ('Anguilla', 'AI', '1'),
#  ('Antigua and Barbuda', 'AG', '1'),
#  ('Argentina', 'AR', '1'),
#  ('Armenia', 'AM', '1'),
#  ('Aruba', 'AW', '1'),
#  ('Australia', 'AU', '1'),
#  ('Austria', 'AT', '1'),
#  ('Azerbaijan', 'AZ', '0'),
#  ('Bahamas', 'BS', '1'),
#  ('Bahrain', 'BH', '1'),
#  ('Bangladesh', 'BD', '1'),
#  ('Barbados', 'BB', '1'),
#  ('Belarus', 'BY', '1'),
#  ('Belgium', 'BE', '1'),
#  ('Belize', 'BZ', '1'),
#  ('Benin', 'BJ', '1'),
#  ('Bermuda', 'BM', '1'),
#  ('Bhutan', 'BT', '0'),
#  ('Bolivia', 'BO', '1'),
#  ('Bonaire; St. Eustatius and Saba', 'BQ', '1'),
#  ('Bosnia and Herzegovina', 'BA', '1'),
#  ('Botswana', 'BW', '1'),
#  ('Brazil', 'BR', '1'),
#  ('British Virgin Islands', 'VG', '1'),
#  ('Brunei', 'BN', '1'),
#  ('Bulgaria', 'BG', '1'),
#  ('Burkina Faso', 'BF', '1'),
# ...
